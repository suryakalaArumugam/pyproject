# %% [markdown]
#                              LANGUAGE LEARNING APPLICATION SOURCE CODE

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <!-- <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"> -->
    <!-- <script type="text/javascript" src="https://gc.kis.v2.scr.kaspersky-labs.com/58C8E006-EBD5-744B-9A37-5E551201E617/main.js" charset="UTF-8" defer></script> -->
    <!--<script src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js" defer></script>-->
    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" defer></script>
    <script src="js/jquery.min.js"></script>
    <script src="js/bootstrap.bundle.min.js"></script>
    <script src="https://www.google.com/recaptcha/api.js"></script>
    <script src="https://kit.fontawesome.com/1d06adb4a8.js" crossorigin="anonymous"></script>
    <script src="js/csi.js"></script>
    <base href="">
    <meta charset="utf-8">
    <meta name="apple-mobile-web-app-capable" content="yes">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
    <meta property="og:title" content="Start Your Free Trial â Playablo LMS | India, US, UK, Singapore" />
    <meta property="og:url" content="http://playablo.com" />
    <meta property="og:type" content="website" />
    <meta property="og:locale" content="en_US" />
    <meta property="og:image" content="http://playablo.com/images/landing.png">
    <meta property="og:description" content="Reinventing Learning,through gamification" />

    <meta name="theme-color" content="#317EFB"/>
    <!-- this is new modified title, meta kewords and meta descriptions -->
    <title>Start Your Free Trial â Playablo LMS | India, US, UK, Singapore</title>
    <meta name="description"
        content="What is LMS software? How is PlayAblo, a self-hosted LMS website, the best enterprise LMS for your employee training LMS needs?">
       <!-- <meta name="description"
        content="Playablo is reinventing learning through gamification. Playablo is an amazing Educational Gamification App for kids of Class 1, Class 2, Class 3, Class 4,Class 5.You can help your kids learn through games.">-->
    <meta name="keywords"
        content="Educational Gaming app, Educational app for kids,Learning app for children,Educational app,Gaming app Playablo,Educational App,learn via Games,Learning App">

    <!-- GAK Added Page Icon -->
    <link rel="icon" href="images/PlayAblo_Icon.ico" type="image/x-icon">
    <!-- <link href="https://www.cssscript.com/wp-includes/css/sticky.css" rel="stylesheet" type="text/css"> -->
    <link rel="stylesheet" href="css/bootstrap.min.css">
    <!-- <link rel="stylesheet" href="css/animate.min.css"> -->
    <link rel="stylesheet" href="css/style.css">
    <link rel="stylesheet" href="css/responsive.css">
    <!-- <link rel="stylesheet" href="css/full-slider.css"> -->
    <link rel="stylesheet" href="css/carousel.css">
   <!--<script
    src="https://code.jquery.com/jquery-2.2.0.min.js"
    type="text/javascript"
  ></script>--> 
  <script src="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.6.0/slick.js"></script>
  <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/js/bootstrap.min.js"></script>
  <link
    href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css"
    rel="stylesheet"
  />
    <link
    rel="stylesheet"
    href="https://cdnjs.cloudflare.com/ajax/libs/intl-tel-input/17.0.8/css/intlTelInput.css"
  />
  <script src="https://cdnjs.cloudflare.com/ajax/libs/intl-tel-input/17.0.8/js/intlTelInput.min.js"></script>
    <!-- <link href="//netdna.bootstrapcdn.com/bootstrap/3.1.0/css/bootstrap.min.css" rel="stylesheet" id="bootstrap-css">
    <script src="//netdna.bootstrapcdn.com/bootstrap/3.1.0/js/bootstrap.min.js"></script>
    <script src="//code.jquery.com/jquery-1.11.1.min.js"></script> -->
    <!-- Facebook Pixel Code -->
    <!-- <link href="hover.css" rel="stylesheet" media="all"> -->
    <!-- <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script> -->
    <style id="fonts1" type="text/css">
        @font-face {
            font-family: ProximaNova-Black;
            src: url("font_otf/ProximaNova-Black.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Bold;
            src: url("font_otf/ProximaNova-Bold.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Boldlt;
            src: url("font_otf/ProximaNova-Boldlt.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNovaCond-Light;
            src: url("font_otf/ProximaNovaCond-Light.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNovaCond-LightIt;
            src: url("font_otf/ProximaNovaCond-LightIt.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNovaCond-Regular;
            src: url("font_otf/ProximaNovaCond-Regular.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNovaCond-Semibold;
            src: url("font_otf/ProximaNovaCond-Semibold.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Extrabold;
            src: url("font_otf/ProximaNova-Extrabold.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Light;
            src: url("font_otf/ProximaNova-Light.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Regular;
            src: url("font_otf/ProximaNova-Regular.otf") format("opentype");
        }

        @font-face {
            font-family: ProximaNova-Semibold;
            src: url("font_otf/ProximaNova-Semibold.otf") format("opentype");
        }

        @font-face {
            font-family: Roboto-Bold;
            src: url("font_otf/Roboto-Bold.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-Bold;
            src: url("poppins/Poppins-Bold.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-SemiBold;
            src: url("poppins/Poppins-SemiBold.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-Medium;
            src: url("poppins/Poppins-Medium.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-Regular;
            src: url("poppins/Poppins-Regular.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-Light;
            src: url("poppins/Poppins-Light.ttf") format("truetype");
        }

        @font-face {
            font-family: Poppins-ExtraLight;
            src: url("poppins/Poppins-ExtraLight.ttf") format("truetype");
        }
        
    </style>

    <script id="cookieWarn" type="text/javascript" src="js/cookie-warn.js"></script>
    <style type="text/css">
        
        
            .iti__country-list{
            width: 400%;
        }
        
        .iti {
                width: 100% !important;
            }
		.flex-container {
		  display: flex;
		  flex-flow: row wrap;
		  justify-content: space-around;
		  padding: 0;
		  margin: 0;
		  list-style: none;
		}

		.flex-item {
		  padding: 5px;
		  width: 69px;
		  margin-top: 10px;
		  text-align: center;
		}
        #cookieWarnBox {


            transition: all 0.4s ease-in-out;
            position: fixed;
            z-index: 999999;
            left: 0;
            right: 0;
            text-align: center;
            padding: 0px;
            background-color: transparent !important;
        }

        #output {
            color: orange;
            letter-spacing: 2px;
        }

        #cookieWarnBox.loaded {
            opacity: 0.9;
            bottom: -17px;
        }

        .btn-success {
            color: #fff;
            background-color: #f87253;
            border-color: #f87253;
            /* float: right; */
        }

        .text {
            color: rgb(71, 69, 69);
            background-color: #e7e7e7;
            line-height: 1.8em;
            width: 100%;
            padding: 1%;
            font-family: 'Poppins-Regular';
            /* text-align: left; */
            padding: 2% 9%;
            font-size: 13px;
        }

        #myCaptchaHome div {
            width: 100% !important;
            text-align: center !important;
        }

        body {
            overflow-x: hidden !important;
            background-color: #f3f3f3;
        }

        .edWinner {
            width: 75%;
        }

        .container {
            margin-top: 20px;
        }
        .navbar-fixed-top.scrolled {
            background-color: rgb(220 220 220 / 95%) !important;
            transition: background-color 200ms linear;
        }

        .navbar-fixed-top.scrolled .nav-link {
            color: #555;
        }
        .navbar-fixed-top.scrolled {
            background-color: rgb(220 220 220 / 88%) !important;
            transition: background-color 200ms linear;
        }

        .navbar-fixed-top.scrolled .nav-link {
            color: #555;
        }

        .sticky {
            margin-top: -34px;
        }

        /* Carousel Styles */

        .carousel-inner .bg_overlay {
            width: 100%;
            max-height: 661px;
        }

        /* Carousel Header Styles */
        .header-text {
            position: absolute;
            top: 35%;
            left: 1.8%;
            right: auto;
            width: 96.66666666666666%;
            color: #e2e2e2;
            font-size: 20px;
            letter-spacing: 1px;
        }

        .header-text h2 {
            font-size: 50px;
            color: #fff;
            font-weight: 600;
        }

        .header-text h2 span {
            padding: 10px;
            color: orange;
        }

        .header-text h3 span {
            padding: 15px;
        }

        .carousel-control.left,
        .carousel-control.right {
            opacity: 1;
            filter: alpha(opacity=100);
            background-image: none;
            background-repeat: no-repeat;
            text-shadow: none;
            margin-right: 95px;
        }

        .carousel-indicators .active {
            background-color: #424242;
            opacity: 1;
        }

        .carousel-indicators li {
            background-color: #424242;
            opacity: 0.4;
        }

        .carousel-control {
            color: #e2e2e2;
        }

        .carousel-control {
            width: 90;
        }

        .glyphicon {
            color: #d6d0d0;
        }

        .carousel-control .glyphicon-chevron-right,
        .carousel-control .icon-next {
            margin-right: -97px !important;
        }

        .header-text h2 {
            font-size: 40px;
        }

        .header-text h2 span {
            background-color: #2980b9;
            padding: 10px;
        }

        .header-text h3 span {
            background-color: #000;
            padding: 15px;
        }

        .btn-min-block {
            min-width: 170px;
            line-height: 26px;
        }

        .btn-theme {
            color: #fff;
            background-color: transparent;
            border: 2px solid #fff;
            margin-right: 15px;
        }

        .btn-theme:hover {
            color: #000;
            background-color: #fff;
            border-color: #fff;
        }

        .allrsrvHome {
            height: 21px;
            /* padding-top: 3px; */
            color: #838383;
            float: left;
            font-size: 10px;
            font-family: Poppins-Regular;
            letter-spacing: 0.45px;
            /* border-right: 2px solid #8080805c; */
            text-align: center;
        }

        .item1Tab {
            background-image: url("img/home-exp.png");
            background-repeat: no-repeat;
            height: 766px;
        }

        .item2Tab {
            background-image: url("img/school-exp.png");
            background-repeat: no-repeat;
            height: 766px;
        }

        .item3Tab {
            background-image: url("img/ngo-exp.png");
            background-repeat: no-repeat;
            height: 766px;
        }

        .slidesH4 {
            FONT-FAMILY: ProximaNova-Bold;
            font-size: 2.5em;
            text-align: left;
        }

        .slidesB {
            FONT-FAMILY: ProximaNova-Bold;
            font-size: 1.5em;
        }

        .imageset_new {
            width: 100% !important;
            text-align: center;
            top: 30px;
        }

        .slide3Tab {
            text-align: end;
            position: relative;
            margin-top: 5%;
            /* left: 49%; */
        }

        .slide2Tab {
            text-align: end;
            position: relative;
            margin-top: 9%;
            /* left: 49%; */
        }

        .ulSocialMediaIndex {
            /*margin-top: 20%;*/
            margin-top: 15%;
        }
        .aFooter {
    color: #838383!important;
    font-size: 10px;
    font-family: Poppins-Regular;
}
        @media only screen and (min-width: 320px) and (max-width: 359px) {

            html {
                overflow-x: hidden;
            }

            .socilalMediaPlayabloIndex {
                margin-left: 19%;
                margin-top: 5%;
            }

            #bs-example-navbar-collapse-1 {
                width: 100%;
                background-color: rgba(0, 0, 0, 0.9);
            }

            /* .liMoz1 {
                margin-left: -15%;
            } */


            .thirdImg {
                position: absolute;
                margin-top: 67%;
                width: 77%;
                margin-left: -91%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 37%;
                padding: 0 4% 0 13%;
                width: 67%;
                height: 100%;
                background: linear-gradient(to right, rgba(255, 255, 255, 0), #FFFFFF 18%);
            }

            .slidesH4 {
                font-size: 0.8em;
            }

            .slidesB {
                font-size: 0.6em;
            }

            .learnBtn1Tab {
                margin-top: 86%;
                margin-right: 26%;
                height: 29px;
                content: url(img/learnMoreM.png);
            }

            .item3Tab {
                height: 567px;
                background-size: cover;
                background-image: url(img/ngo-exp.png);
                background-position-x: 87%;
            }

            .item2Tab {
                height: 445px;
                background-size: cover;
                background-image: url(img/school-exp.png);
                background-position-x: 87%;
                background-repeat: no-repeat;
            }

            .item1Tab {
                background-image: url(img/home-exp.png);
                background-repeat: no-repeat;
                height: 470px;
                background-size: auto;
                /* background-position-x: 13%; */
                background-size: cover;
            }

            .slide2Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 16%);
                left: -6%;
                padding: 12% 0% 0 5%;
                width: 65%;
                height: 100%;
            }

            .learnBtn2Tab {
                margin-left: -125%;
                margin-top: 35%;
                height: 29px;
                content: url(img/learnMoreM.png);
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -4%;
                width: 65%;
                height: 100%;
                padding: 3% 1% 0 7%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }

            .learnBtn3Tab {
                margin-right: 25%;
                margin-top: 41%;
                height: 29px;
                content: url(img/learnMoreM.png);
            }

            .thirdImgItem3 {
                margin-top: 10%;
                margin-left: 17%;
            }

            .imageset_new {
                width: 131% !important;
                text-align: center;
                top: 32px;
                margin-left: -17%;
            }

            .allrsrvHome {
                color: #838383;
                font-size: 0.7em;
            }

            .aFooter {
                color: #838383 !important;
                /*font-size: 0.8em;*/
                font-size: 12px;
                font-family: Poppins-Regular;
                /*background-color: rgba(0, 0, 0, 0.85);*/
            }

            .divFooter {
                float: left;
                width: 100%;
            }

            footer {
                background: none;
                /*position: static;*/
                width: 100%;
                bottom: 0;
                /* display: flex; */
                padding-top: 2%;
                z-index: 111;
                /* height: 148px; */
            }

        }

        @media only screen and (min-width: 360px) and (max-width: 374px) {


            html {
                overflow-x: hidden;
            }

            .socilalMediaPlayabloIndex {
                margin-left: 19%;
                margin-top: 5%;
            }

            #bs-example-navbar-collapse-1 {
                width: 100%;
                background-color: rgba(0, 0, 0, 0.9);
            }

            /* .liMoz1 {
                margin-left: -15%;
            } */


            .thirdImg {
                position: absolute;
                margin-top: 61%;
                width: 77%;
                margin-left: -91%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 38%;
                padding: 0 4% 0 13%;
                width: 67%;
                height: 100%;
                background: linear-gradient(to right, rgba(255, 255, 255, 0), #FFFFFF 31%);
            }

            .slidesH4 {
                font-size: 1em;
            }

            .slidesB {
                font-size: 0.7em;
            }

            .learnBtn1Tab {
                margin-top: 86%;
                margin-right: 26%;
                height: 45px;
                content: url(img/learnMoreM.png);
            }

            .item3Tab {
                height: 567px;
                background-size: cover;
                background-image: url(img/ngo-exp.png);
                background-position-x: 87%;
            }

            .item2Tab {
                height: 445px;
                background-size: cover;
                background-image: url(img/school-exp.png);
                background-position-x: 85%;
                background-repeat: no-repeat;
            }

            .item1Tab {
                background-image: url(img/home-exp.png);
                background-repeat: no-repeat;
                height: 561px;
                background-size: auto;
                background-position-x: 13%;
                background-size: cover;
            }

            .slide2Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 16%);
                left: -4%;
                padding: 12% 0% 0 7%;
                width: 68%;
                height: 100%;
            }

            .learnBtn2Tab {
                margin-left: -125%;
                margin-top: 35%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -4%;
                width: 72%;
                height: 100%;
                padding: 3% 1% 0 7%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }

            .learnBtn3Tab {
                margin-right: 25%;
                margin-top: 27%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .thirdImgItem3 {
                margin-top: 10%;
                margin-left: 17%;
            }

            .imageset_new {
                width: 131% !important;
                text-align: center;
                top: 32px;
                margin-left: -17%;
            }

            .allrsrvHome {
                color: #838383;
            }

            .aFooter {
                color: #838383 !important;
                /*font-size: 0.95em;*/
                font-size: 12px;
                font-family: Poppins-Regular;
                /*background-color: rgba(0, 0, 0, 0.85);*/
            }

            .divFooter {
                float: left;
                width: 100%;
            }

            footer {
                background: none;
                /*position: fixed;*/
                width: 100%;
                bottom: 0;
                /* display: flex; */
                padding-top: 2%;
                z-index: 111;
                /* height: 148px; */
            }
        }

        @media only screen and (min-width: 375px) and (max-width: 411px) {
			.flex-container {
			  display: flex;
			  flex-flow: row wrap;
			  justify-content: space-around;
			  padding: 0;
			  margin: 0;
			  list-style: none;
			}

			.flex-item {
			  padding: 5px;
			  width: 40px;
			  margin-top: 10px;
			  text-align: center;
			}
            html {
                overflow-x: hidden;
            }

            .socilalMediaPlayabloIndex {
                margin-left: 19%;
                margin-top: 5%;
            }

            #bs-example-navbar-collapse-1 {
                width: 100%;
                background-color: rgba(0, 0, 0, 0.9);
            }

            /* .liMoz1 {
                margin-left: -15%;
            } */


            .thirdImg {
                position: absolute;
                margin-top: 54%;
                width: 77%;
                margin-left: -91%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 37%;
                padding: 0 4% 0 13%;
                width: 67%;
                height: 100%;
                background: linear-gradient(to right, rgba(255, 255, 255, 0), #FFFFFF 18%);
            }

            .slidesH4 {
                font-size: 1em;
            }

            .slidesB {
                font-size: 0.7em;
            }

            .learnBtn1Tab {
                margin-top: 86%;
                margin-right: 26%;
                height: 45px;
                content: url(img/learnMoreM.png);
            }

            .item3Tab {
                height: 567px;
                background-size: cover;
                background-image: url(img/ngo-exp.png);
                background-position-x: 87%;
            }

            .item2Tab {
                height: 445px;
                background-size: cover;
                background-image: url(img/school-exp.png);
                background-position-x: 87%;
                background-repeat: no-repeat;
            }

            .item1Tab {
                background-image: url(img/home-exp.png);
                background-repeat: no-repeat;
                height: 551px;
                background-size: auto;
                background-position-x: 13%;
                background-size: cover;
            }

            .slide2Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 16%);
                left: -4%;
                padding: 12% 0% 0 7%;
                width: 68%;
                height: 100%;
            }
            
            .learnBtn2Tab {
                margin-left: 5%;
                margin-top: 35%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -4%;
                width: 72%;
                height: 100%;
                padding: 3% 1% 0 7%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }

            .learnBtn3Tab {
                margin-right: 25%;
                margin-top: 21%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .thirdImgItem3 {
                margin-top: 10%;
                margin-left: 17%;
            }

            .imageset_new {
                width: 131% !important;
                text-align: center;
                top: 32px;
                margin-left: -17%;
            }

            .allrsrvHome {
                color: #838383;
            }

            .aFooter {
                color: #838383 !important;
                /*font-size: 1em;*/
                font-size: 12px;
                font-family: Poppins-Regular;
                /*background-color: rgba(0, 0, 0, 0.85);*/
            }

            .divFooter {
                float: left;
                width: 100%;
            }

            footer {
                background: none;
                /*position: fixed;*/
                width: 100%;
                bottom: 0;
                /* display: flex; */
                padding-top: 2%;
                z-index: 111;
                /* height: 148px; */
            }
        }


        @media only screen and (min-width: 412px) and (max-width: 765px) {
			.flex-container {
			  display: flex;
			  flex-flow: row wrap;
			  justify-content: space-around;
			  padding: 0;
			  margin: 0;
			  list-style: none;
			}

			.flex-item {
			  padding: 5px;
			  width: 40px;
			  margin-top: 10px;
			  text-align: center;
			}
            html {
                overflow-x: hidden;
            }

            .socilalMediaPlayabloIndex {
                margin-left: 19%;
                margin-top: 5%;
            }

            #bs-example-navbar-collapse-1 {
                width: 100%;
                background-color: rgba(0, 0, 0, 0.9);
            }

            /* .liMoz1 {
                margin-left: -15%;
            } */


            .thirdImg {
                position: absolute;
                margin-top: 54%;
                width: 77%;
                margin-left: -91%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 37%;
                padding: 0 4% 0 13%;
                width: 67%;
                height: 100%;
                background: linear-gradient(to right, rgba(255, 255, 255, 0), #FFFFFF 18%);
            }

            .slidesH4 {
                font-size: 1em;
            }

            .slidesB {
                font-size: 0.7em;
            }

            .learnBtn1Tab {
                margin-top: 86%;
                margin-right: 26%;
                height: 45px;
                content: url(img/learnMoreM.png);
            }

            .item3Tab {
                height: 567px;
                background-size: cover;
                background-image: url(img/ngo-exp.png);
                background-position-x: 87%;
            }

            .item2Tab {
                height: 445px;
                background-size: cover;
                background-image: url(img/school-exp.png);
                background-position-x: 87%;
                background-repeat: no-repeat;
            }

            .item1Tab {
                background-image: url(img/home-exp.png);
                background-repeat: no-repeat;
                height: 561px;
                background-size: auto;
                background-position-x: 13%;
                background-size: cover;
            }

            .slide2Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 16%);
                left: -4%;
                padding: 12% 0% 0 7%;
                width: 68%;
                height: 100%;
            }

            .learnBtn2Tab {
                margin-left: -125%;
                margin-top: 35%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -4%;
                width: 72%;
                height: 100%;
                padding: 3% 1% 0 7%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }

            .learnBtn3Tab {
                margin-right: 25%;
                margin-top: 27%;
                height: 47px;
                content: url(img/learnMoreM.png);
            }

            .thirdImgItem3 {
                margin-top: 10%;
                margin-left: 17%;
            }

            .imageset_new {
                width: 131% !important;
                text-align: center;
                top: 32px;
                margin-left: -17%;
            }

            .allrsrvHome {
                color: #838383;
            }

            .aFooter {
                color: #838383 !important;
                /*font-size: 1.1em;*/
                font-size: 12px;
                font-family: Poppins-Regular;
                /*background-color: rgba(0, 0, 0, 0.85);*/
            }

            .divFooter {
                float: left;
                width: 100%;
            }

            footer {
                background: none;
                /*position: fixed;*/
                width: 100%;
                bottom: 0;
                /* display: flex; */
                padding-top: 2%;
                z-index: 111;
                /* height: 148px; */
            }
        }

        @media only screen and (min-width: 766px) and (max-width: 1000px) {
            html {
                overflow-x: hidden;
            }

            .thirdImg {
                position: absolute;
                margin-top: 43%;
                width: 64%;
                margin-left: -72%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 53%;
            }

            .slidesH4 {
                font-size: 1.5em;
            }

            .slidesB {
                font-size: 1em;
            }

            .learnBtn1Tab {
                margin-top: 60%;
                margin-right: 11%;
            }

            .item3Tab {
                height: 641px;
                background-size: contain;
            }

            .item2Tab {
                height: 577px;
                background-size: contain;
            }

            .slide2Tab {
                width: 65%;
            }

            .learnBtn2Tab {
                margin-left: 65%;
                margin-top: 25%;
            }

            .slide3Tab {
                width: 66%;
            }

            .learnBtn3Tab {
                margin-right: 25%;
                margin-top: 15%;
            }

            .thirdImgItem3 {
                margin-top: 10%;
                margin-left: 17%;
            }

            .divFooter {
                float: right;
                margin-right: -6%;
                /* margin-left: 21%; */
                width: 91%;
            }
        }

        @media only screen and (min-width: 1000px) and (max-width: 1024px) {
            .footerTab {
                float: right;
                margin-right: -11%;
                /* margin-left: 21%; */
                width: 71%;
            }

            .bodyWeb {
                display: none;
            }

            .bodyTab {
                display: block;
            }
        }

        @media only screen and (min-width: 338px) and (max-width: 765px) {
            .learnBtn2Tab {
                margin-left: 47%;
                -webkit-margin-start: 47%;
                ;
            }
        }

        @media only screen and (min-width: 510px) and (max-width: 650px) {
            .thirdImg {
                position: absolute;
                margin-top: 35%;
                width: 77%;
                margin-left: -91%;
            }

            .learnBtn1Tab {
                margin-top: 61%;
                margin-right: 26%;
                height: 45px;
                content: url(img/learnMoreM.png);
            }
        }

        @media only screen and (min-width: 651px) and (max-width: 765px) {
            ul.ulSocialMediaIndex {
                margin-left: 100%;
            }

            .liMoz1 {
                margin-left: -9%;
            }

            .thirdImg {
                position: absolute;
                margin-top: 23%;
                width: 77%;
                margin-left: -91%;
            }

            .learnBtn1Tab {
                margin-top: 37%;
                margin-right: 26%;
                height: 45px;
                content: url(img/learnMoreM.png);
            }

            .learnBtn2Tab {
                margin-left: 45%;
                margin-top: 2%;
            }

            .learnBtn3Tab {
                margin-right: 31%;
                margin-top: 11%;
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -2%;
                width: 72%;
                height: 100%;
                padding: 3% 1% 0 7%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }

            .slide2Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 16%);
                left: -3%;
                padding: 12% 0% 0 8%;
                width: 65%;
                height: 100%;
            }

            .slide1 {
                text-align: end;
                position: relative;
                margin-top: 23%;
                left: 37%;
                padding: 0 5% 0 13%;
                width: 65%;
                height: 100%;
                background: linear-gradient(to right, rgba(255, 255, 255, 0), #FFFFFF 18%);
            }

            .slide3Tab {
                text-align: end;
                position: relative;
                margin-top: 0%;
                left: -2%;
                width: 72%;
                height: 100%;
                padding: 3% 1% 0 9%;
                background: linear-gradient(to left, rgba(255, 255, 255, 0), #FFFFFF 49%);
            }
        }

        @-moz-document url-prefix() {

            .liMoz2 {
                margin-left: 4% !important;
                margin-top: -6% !important;

            }

            .ulSocialMediaIndex {
                margin-top: 40%;
            }

            .navbar-nav.navbar-right {
                margin-left: -53%;
                margin-top: 6%;
            }

            .socilalMediaPlayabloIndex {
                padding: 0 !important;
            }
        }
        
        @media only screen and (min-width: 700px) {

            /*.navbar-header.single-page-nav{
        width:29% !important;
    }*/
            /*.edWinner{
        width: 75% !important;
    }*/
            .collapse.navbar-collapse {
                width: 66.66666667% !important;
            }
        }

        @media only screen and (min-width: 300px) and (max-width: 669px) {
            .navbar-header.single-page-nav {
                width: 100% !important;
            }

            .edWinner {
                width: 75% !important;
            }

            .collapse.navbar-collapse {
                width: 100% !important;
            }

            .bodyWeb {
                display: none;
            }

            .bodyTab {
                display: block;
            }

            .edWinnerPopUp {
                width: 100% !important;
                margin-top: 17%;
            }

            #popUpContainer {
                margin-top: 45% !important;
            }
        }

        @media only screen and (min-width: 1100px) {
            .bodyWeb {
                display: block;
            }

            .bodyTab {
                display: none;
            }
        }

        @media only screen and (min-width: 600px) and (max-width: 1099px) {
            #popUpContainer {
                margin-top: 51% !important;
            }
        }



        #popUpContainer {
            margin-top: 17%;
            text-align: center;
        }

        .popupClose {
            margin-top: -9%;
            margin-right: 17%;
            color: #ffffff;
            font-size: 5em;
        }

        .fade.in {
            opacity: 1;
            background: #0f101480;
        }

        .edWinner {
            display: none;
        }

        .pricingDiv {
            /* height: 841px; */
            height: 371px;
            background: #FFFFFF 0% 0% no-repeat padding-box;
            /* box-shadow: 0px 0px 18px #00000036; */
            opacity: 1;
        }

        .users {
            /* padding: 3% 3%;
            width: 97%;
            margin-left: 1%;
            margin-top: 4%;
            border: 1px solid #8C8EC5;
            font-family: Poppins-Regular; */

            /* padding: 2% 3%;
            width: 81%;
            margin-left: 9%;
            margin-top: 1%;
            border: 1px solid #B2B2B2;
            font-family: Poppins-Regular; */

            padding: 3% 3%;
            width: 108%;
            margin-left: -4%;
            margin-top: 0%;
            border: 1px solid #1B1E6F;
            font-family: Poppins-Regular;
            color: #1B1E6F;
        }

        .usersSpan1 {
            float: left;
            font-family: Poppins-Medium;
            color: #919191;
        }

        .usersSpan2 {
            float: right;
            color: #818181;
            font-family: Poppins-Bold;
        }

        .userP1 {
            font-family: Poppins-SemiBold;
            color: #909090;
            padding-bottom: 11%;
        }

        .userP2 {
            font-family: Poppins-Bold;
        }

        .fade.in {
            background: none;
            display: block;
        }

        .fade {
            background: none;
            display: none;
        }

        a.tabBtn.activeTab {
            color: #484848 !important;
            font-family: Poppins-Medium;
            border-bottom: 2px solid #FF3030 !important;
        }

        .enterprise {
            background: #FFFFFF 0% 0% no-repeat padding-box;
            box-shadow: 0px 0px 18px #00000036;
            opacity: 1;
            height: 307px;
        }

        .descriptionP {
            /* padding: 2% 1% 2% 1%;
            text-align: center;
            font-family: Poppins-Regular;
            color: #7D7D7D;
            font-size: 2.5vh; */

            padding: 0% 1% 2% 1%;
            text-align: center;
            font-family: Poppins-Regular;
            color: #7D7D7D;
            font-size: 8px;
            background: white;
        }
        
        .descriptionPMob {

            padding: 0% 1% 2% 1%;
            text-align: center;
            font-family: Poppins-Regular;
            color: #7D7D7D;
            font-size: 11px;
            background: white;
        }

        .btnContainer {
            text-align: center;
            padding: 1%;
            background-color: white;
            margin-bottom: 3%;
        }
        .btnContainerMob {
            text-align: center;
            padding: 1%;
            background-color: white;
            margin-bottom: 3%;
        }

        .btnContainer button {
            background: #EA7421 0% 0% no-repeat padding-box;
            border-radius: 51px;
            opacity: 1;
            border: none;
            color: white;
            padding: 1% 4%;
            font-family: Poppins-Medium;
            font-size: 2.3vh;
        }

.btnContainerMob button {
    background: #EA7421 0% 0% no-repeat padding-box;
    border-radius: 51px;
    opacity: 1;
    border: none;
    color: white;
    padding: 1% 4%;
    font-family: Poppins-Medium;
    font-size: 2.3vh;
}

        button:focus {
            outline: none;
        }

        .errormsgMail,
        .errormsgFname,
        .errormsgLname,
        .errormsgLnameM,
        .errormsgCname,
        .errormsgCnameM,
        .errormsgIname,
        .errormsgIname1,
        .errormsgRname,
        .errormsgRname1,
        .errormsgCountry,
        .errormsgPhone,
        .errormsgPhoneM,
        .errormsgEmpNo,
        .errormsgEmpNoM {
            color: #ee2828;
            font-family: Poppins-Medium;
            text-align: center;
            padding-top: 1%;
            display: none;
        }
        .errormsgMailMob,
        .errormsgFnameMob,
        .errormsgLnameMob,
        .errormsgLnameMMob,
        .errormsgCnameMob,
        .errormsgCnameMMob,
        .errormsgInameMob,
        .errormsgIname1Mob,
        .errormsgRnameMob,
        .errormsgRname1Mob,
        .errormsgCountryMob,
        .errormsgPhoneMob,
        .errormsgPhoneMMob,
        .errormsgEmpNoMob,
        .errormsgEmpNoMMob {
            color: #ee2828;
            font-family: Poppins-Medium;
            text-align: center;
            padding-top: 1%;
            display: none;
        }
        @media only screen and (min-width: 320px) and (max-width: 900px) {

            .signUpContainer {
                background: transparent !important;
                padding: 0 5% 10% !important;
            }

            .pricingDiv {
                height: 537px;
                margin-top: 5%;
            }

            .btnContainer {
                text-align: center;
                padding: 11% !important;
            }
            .btnContainerMob {
                text-align: center;
                padding: 11% !important;
            }
            .btnContainer button {
                background: #EA7421 0% 0% no-repeat padding-box;
                border-radius: 51px;
                opacity: 1;
                border: none;
                color: white;
                padding: 3% 9%;
                font-family: Poppins-Medium;
                font-size: 2.3vh;
            }

.btnContainerMob button {
    background: #EA7421 0% 0% no-repeat padding-box;
    border-radius: 51px;
    opacity: 1;
    border: none;
    color: white;
    padding: 3% 9%;
    font-family: Poppins-Medium;
    font-size: 2.3vh;
}
        }

        .signUpContainer {
            /* background: #DBDEE5; */
            background: #ffffff;
            padding: 1% 5%;
            border-radius: 15px;
        }
        #tothetopbutton {
  display: none;
  position: fixed;
  bottom: 10%;
  left: 42.5%;
  z-index: 99;
  font-size: 18px;
  border: none;
  outline: none;
  background-color: #555;
  color: white;
  cursor: pointer;
  padding: 15px;
  border-radius: 4px;
}

#tothetopbutton:hover {
  background-color: #555;
}
        .item h2,
        .itemH2 {
            font-family: 'Poppins-Medium' !important;
            font-size: 2.5vh !important;
            text-align: center;
            color: white;
            background: linear-gradient(to right, #607AFC, #3B45B2 35%);
            margin: 0;
        }

        ::placeholder {
            color: #AFB1E9;
            opacity: 1;
            /* Firefox */
        }
        #urRole, #indName{
            color: #AFB1E9 !important;
            opacity: 1;
        }

        @media only screen and (min-width: 300px) and (max-width: 1099) {
            .signUpContainer {

                background: transparent !important;
            }

        }

        @media only screen and (min-width: 320px) and (max-width: 365px) {
            .pricingDiv {
                height: 465px !important;
                margin-top: 5%;
            }
        }

        @media only screen and (min-width: 1200px) {
            .navbar-header {
                padding: 10px 20px 23px;
            }
        }
        /*logos slider css*/
   
/* Slider */

.slick-slide {
    margin: 0px 20px;
}

.slick-slide img {
    width: 100%;
}

.slick-slider
{
    position: relative;
    display: block;
    box-sizing: border-box;
    -webkit-user-select: none;
    -moz-user-select: none;
    -ms-user-select: none;
            user-select: none;
    -webkit-touch-callout: none;
    -khtml-user-select: none;
    -ms-touch-action: pan-y;
        touch-action: pan-y;
    -webkit-tap-highlight-color: transparent;
}

.slick-list
{
    position: relative;
    display: block;
    overflow: hidden;
    margin: 0;
    padding: 0;
}
.slick-list:focus
{
    outline: none;
}
.slick-list.dragging
{
    cursor: pointer;
    cursor: hand;
}

.slick-slider .slick-track,
.slick-slider .slick-list
{
    -webkit-transform: translate3d(0, 0, 0);
       -moz-transform: translate3d(0, 0, 0);
        -ms-transform: translate3d(0, 0, 0);
         -o-transform: translate3d(0, 0, 0);
            transform: translate3d(0, 0, 0);
}

.slick-track
{
    position: relative;
    top: 0;
    left: 0;
    display: block;
    overflow: visible;
}
.slick-track:before,
.slick-track:after
{
    display: table;
    content: '';
}
.slick-track:after
{
    clear: both;
}
.slick-loading .slick-track
{
    visibility: hidden;
}

.slick-slide
{
    display: none;
    float: left;
    height: 100%;
    min-height: 1px;
}
[dir='rtl'] .slick-slide
{
    float: right;
}
.slick-slide img
{
    display: block;
}
.slick-slide.slick-loading img
{
    display: none;
}
.slick-slide.dragging img
{
    pointer-events: none;
}
.slick-initialized .slick-slide
{
    display: block;
}
.slick-loading .slick-slide
{
    visibility: hidden;
}
.slick-vertical .slick-slide
{
    display: block;
    height: auto;
    border: 1px solid transparent;
}
.slick-arrow.slick-hidden {
    display: none;
}
.client-name{
    font-size: 14px;
    font-family: Poppins-Regular;
    color: #333;
    white-space: nowrap;
    width: 100%;
    justify-content: space-evenly;
    padding-top: 10%;
    text-align: center;
    overflow: visible;
}
.client-name-1, .client-name-2, .client-name-3, .client-name-4, .client-name-5, .client-name-6,
.client-name-7 , .client-name-8, .client-name-9, .client-name-10, .client-name-11, .client-name-12, .client-name-13, .client-name-14,
.client-name-15, .client-name-16, .client-name-17, .client-name-18, .client-name-19, .client-name-20,
.client-name-21, .client-name-22, .client-name-23, .client-name-24, .client-name-25, .client-name-26,
.client-name-27, .client-name-28, .client-name-29, .client-name-30,
.client-name-31, .client-name-32, .client-name-33, .client-name-34, .client-name-35, .client-name-36,
.client-name-37{
  text-align:center;
  display: none;
}
.nameinslider{
    height: 50px;
}

/*testmonila slider css*/
/* Slideshow container */
.testimonials-slideshow-container {
  position: relative;
  
}

/* Slides */
.testimonials-mySlides {
  display: none;
  padding: 30px 80px;
  text-align: center;
  width: 100%;
}

/* Next & previous buttons */
.testimonials-prev, .testimonials-next {
  cursor: pointer;
  position: absolute;
  top: 50%;
  width: auto;
  margin-top: -30px;
  padding: 16px;
  color: #888;
  font-weight: bold;
  font-size: 20px;
  border-radius: 0 3px 3px 0;
  user-select: none;
}

/* Position the "next button" to the right */
.testimonials-next {
  position: absolute;
  right: 0;
  border-radius: 3px 0 0 3px;
}

/* On hover, add a black background color with a little bit see-through */


/* The dot/bullet/indicator container */
.testimonials-dot-container {
    text-align: center;
    padding: 20px;
    
}
.testiominiqal-text{
    color: #383838;
    font-family: Poppins-Regular;
    font-size: 14px;
    font-style: italic;
}

/* The dots/bullets/indicators */
.testimonials-dot {
  cursor: pointer;
  height: 15px;
  width: 15px;
  margin: 0 2px;
  border: 2px solid #4472c4;
  border-radius: 50%;
  display: inline-block;
  transition: background-color 0.6s ease;
}

/* Add a background color to the active dot/circle */
.active, .testimonials-dot:hover {
  background-color: #4472c4;
}

/* Add an italic font style to all quotes */


/* Add a blue color to the author */
.testimonials-author {
    color: #383838;
    font-family: Poppins-Regular;
    font-size: 21px;
    padding-top: 5%;
    margin-bottom: 0px;
}
.testimonials-prev{
    left: 0;
}
.testimonials-author-position{
    color: #000;
    font-family: Poppins-Regular;
    font-size: 21px;
    font-weight: 600;
}
#view-more-customer{
    background: #D0CECE;
    width: 50%;
    display: flex;
    align-items: center;
    opacity: 1;
    border: none;
    color: white;
    padding: 1%;
    font-family: Poppins-Medium;
    font-size: 2vh;
    margin-top: -18px;
    margin-bottom: 16px;
    justify-content: space-evenly;
}
#view-more-customer .fa-arrow-right{
    font-size: 2vh;
}
#view-more-customer:hover{
    background: #D0CECE !important;
   width: 50%;
    opacity: 1;
    display: flex;
    align-items: center;
    border: none;
    color: white;
    padding: 1%;
    font-family: Poppins-Medium;
    font-size: 2vh;
    margin-top: -18px;
    margin-bottom: 16px;
    justify-content: space-evenly;
}
#sidebar {
    width: 80%;
  
    position: absolute;
}
#sidebar.fixed {
    position: fixed;
    top: 17%;
    width: 40%;
    left: 1%;
    
}
.fotercopyright{
    margin-top: 2%;
    border-top: 1px solid #fff;
    padding-top: 2%;
    display: flex;
    justify-content: space-between;
    align-items: center;
}
.contact-foterinfo{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 15px;
}
.contact-foterinfo a{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 15px;
}
.heading-footer{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 20px;
    font-weight: 700;
    padding-bottom: 4%;
    padding-left: 10px;
}
.heading-footer2{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 20px;
    font-weight: 700;
    padding-bottom: 4%;
   
}
.footer-copyright-text{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 15px;
    margin-bottom: 0px;
                margin-top: 6px;
}
.leftFooterlink{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 10px;
    white-space: nowrap;
}
.footertoprows{
    display: flex;
    justify-content: space-between;
}
.contact-footer-row{
    width: 30%;
}
.footer-logos{
    padding: 0;
                width: 7%;
                margin-bottom: 0px;
                margin-top: 6px;
}
.footerlogo1{
    width: 50%;
}
.footerlogo2{
    width: 41%;
    background: #4385f4;
    border-radius: 25%;
}
@media screen and (max-width: 768px) {
    .footertoprows , .fotercopyright{
    display: block !important;
    justify-content: space-between;
}
.contact-footer-row{
    width: 100%;
}
.footer-logos{
    text-align: center;
    width: 100%;
             
}
.footerlogo1{
    width: 30%;
}
.footerlogo2{
    width: 25%;
}
.footer-copyright-text{
    margin-top: 36%;
    margin-bottom: 5%;
}
.heading-footer{
    margin-top: 20%;
}
.heading-footer2{
    margin-top: 20%;
    padding-left: 10px;
}
.link-privacy-footer{
    padding-bottom: 7%;
}
}
.contoury-name-loc{
    color: #fff !important;
    font-family: Poppins-Light;
    font-size: 15px;
    vertical-align: top;
    text-align: center;
}
.grecaptcha-badge { visibility: hidden; }
    </style>
    <script>
        (function (i, s, o, g, r, a, m) {
            i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
                (i[r].q = i[r].q || []).push(arguments)
            }, i[r].l = 1 * new Date(); a = s.createElement(o),
                m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
        })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');

        ga('create', 'UA-93738806-1', 'auto');
        ga('send', 'pageview');
    </script>

    <!-- Global site tag (gtag.js) - Google Ads: 935460323 -->
    <script async src="https://www.googletagmanager.com/gtag/js?id=AW-935460323"></script>
    <script> window.dataLayer = window.dataLayer || []; function gtag() { dataLayer.push(arguments); } gtag('js', new Date()); gtag('config', 'AW-935460323');</script>
    <!-- Event snippet for Submit CL lead form conversion page In your html page, add the snippet and call gtag_report_conversion when someone clicks on the chosen link or button. -->
    <script> function gtag_report_conversion(url) { var callback = function () { if (typeof (url) != 'undefined') { window.location = url; } }; gtag('event', 'conversion', { 'send_to': 'AW-935460323/w6QpCOyM2egBEOP7h74D', 'event_callback': callback }); return false; }</script>
    <!-- --------------------------------------------------------------------------------------------------- -->
</head>

<body>
   
        <div class="container" style="width: 100%; height:15%;">
            <div class="row">
                <!-- <div class="col-md-4 col-lg-4 col-sm-4 col-xs-12"></div> -->
                <nav class="navbar navbar-fixed-top sticky" style="height: auto;border: none; margin-top: 0px;">
                    
                <div class="navbar-header single-page-nav col-md-12 col-lg-12 hidden-sm hidden-xs"
                    style="text-align: center;">
                    <!-- <div class="col-md-2 col-lg-2 col-sm-12 col-xs-12">
                        <a href="index.html" target="_blank">
                        <img src="img/freeTrial/logo.svg" class="logo_mob1" style="width: 100%;">
                        </a>
                    </div> -->
                    <div class="col-md-5 col-lg-5 hidden-sm hidden-xs"><img src="img/freeTrial/logo.svg" class="logo_mob1" style="width: 40%; float: left;padding-left: 10%;"></div>
                    <div class="col-md-5 col-lg-5 col-sm-12 col-xs-12" style="color: #1B1E6F;">
                        <p style="
        font-family: 'Poppins-Bold';
        font-size: 2.7vh;
    ">PlayAbloâ¢ï¸ | SaaS based LMS for Workplaces</p>
                        <p style="
        font-family: 'Poppins-Regular';
        font-size: 2.5vh;
    "> Built for the remote and mobile workforce</p>
                    </div>
                    <!-- <span class="col-md-6 col-lg-6 col-sm-6 col-xs-4"><img class="edWinner" src="img/edWinner.png"></span> -->
                </div>
            </nav>
                <!-- for mobile view navbar starts  -->
                <div class="navbar-header single-page-nav hidden-md hidden-lg col-sm-4 col-xs-12"
                    style="text-align: center;height: auto;">
                    <div class="col-md-2 col-lg-2 col-sm-12 col-xs-12">
                       <a href="index.html" target="_blank"> <img src="img/freeTrial/logo.svg" class="logo_mob1" style="width: 47%;padding: 1% 2% 5%;"></a>
                    </div>
                    <div class="col-md-5 col-lg-5 hidden-sm hidden-xs"></div>
                    <div class="col-md-5 col-lg-5 col-sm-12 col-xs-12" style="color: #1B1E6F;">
                        <p style="
        font-family: 'Poppins-Bold';
        font-size: 2vh;
        margin: 3px;
    ">PlayAbloâ¢ï¸ | SaaS based LMS for Workplaces</p>
                        <p style="
        font-family: 'Poppins-Regular';
        font-size: 1.9vh;
    "> Built for the remote and mobile workforce</p>
                    </div>
                    <!-- <span class="col-md-6 col-lg-6 col-sm-6 col-xs-4"><img class="edWinner" src="img/edWinner.png"></span> -->
                </div>
                <!-- for mobile view navbar ends  -->
    
    
            </div>
    
        </div>
    
    


    
        <!--Zoho Campaigns Web-Optin Form's Header Code Starts Here-->

<script type="text/javascript" src="https://iuvd.campaign-view.com/js/optin.min.js" onload="setupSF('sf3z9018f0b7507bb5d1bec56a025f264cdf62229bc41f7f4204c8b0ec8eea915fa6','ZCFORMVIEW',false,'light',false,'0')"></script>
<script type="text/javascript">
	function runOnFormSubmit_sf3z9018f0b7507bb5d1bec56a025f264cdf62229bc41f7f4204c8b0ec8eea915fa6(th){
		/*Before submit, if you want to trigger your event, "include your code here"*/
	};
</script>

<style>
.quick_form_5_css * {
    -webkit-box-sizing: border-box !important;
    -moz-box-sizing: border-box !important;
    box-sizing: border-box !important;
    overflow-wrap: break-word
}
.SIGNUP_FLD input.inputText:active, .SIGNUP_FLD input.inputText:focus, .SIGNUP_FLD input.inputText:hover{
    background-color: white !important;
}
.SIGNUP_FLD input.inputBtn:active, .SIGNUP_FLD input.inputBtn:focus, .SIGNUP_FLD input.inputBtn:hover{
    background-color: rgb(67, 67, 67) !important;
}
@media only screen and (max-width: 600px) {.quick_form_5_css[name="SIGNUP_BODY"] { width: 100% !important; min-width: 100% !important; margin: 0px auto !important; padding: 0px !important } .SIGNUP_FLD { width: 90% !important; margin: 10px 5% !important; padding: 0px !important } .SIGNUP_FLD input { margin: 0 !important } }
</style>

    <!-- form section   -->


    <!-- carousel starts  -->
    <div class="container hidden-lg hidden-md">
        <div class="row">
            <!-- Carousel -->
            <div id="carousel-example-generic" class="carousel slide" data-interval="10000" data-ride="carousel" style="
            height: 325px;margin-top: 6%;
        ">
                <!-- Indicators -->
                <ol class="carousel-indicators">
                    <li data-target="#carousel-example-generic" data-slide-to="0" class="active"></li>
                    <li data-target="#carousel-example-generic" data-slide-to="1"></li>
                    <li data-target="#carousel-example-generic" data-slide-to="2"></li>
                    <li data-target="#carousel-example-generic" data-slide-to="3"></li>
                </ol>
                <!-- Wrapper for slides -->
                <h2 class="itemH2">
                    <span>Award Winning LMS for Enterprises</span>
                </h2>
                <div class="carousel-inner">
                    <div class="item active">

                        <div class="col-lg-12 col-md-12 co-sm-12 col-xs-12 videoContainer" style="padding: 0;">
                            <!-- <iframe class="mySlides" width="100%" height="190"
                                src="https://www.youtube.com/embed/PIqB4ughbFY?enablejsapi=1" style="border: none;">
                            </iframe> -->

                            <div class="youtube-player" data-id="PIqB4ughbFY" data-related="0" data-control="1"
                                data-info="1" data-fullscreen="1"
                                style="width:100%;display: block; position: relative;cursor: pointer;max-height:360px;height:190px; overflow:hidden;padding-bottom:56.25%;margin:0 auto;">
                                <iframe src="//www.youtube.com/embed/PIqB4ughbFY?autoplay=0&autohide=2&border=0&wmode=opaque&enablejsapi=1&rel=0&controls=1&showinfo=1" frameborder="0" id="youtube-iframe" style="width: 100%; height: 100%; position: absolute; top: 0; left: 0;" allowfullscreen=""></iframe>
                            </div>
                        </div>

                        <h2 style="
    /* font-size: 2vh !important; */
    padding: 00;
">
                            <span>Take a Look</span>
                        </h2>

                        <!-- </div>
                        </div> -->
                        <!-- /header-text -->
                    </div>
                    <div class="item">
                        <!-- <h2>
                            <span>Award Winning LMS for Enterprises</span>
                        </h2> -->
                        <!-- <img src="http://unsplash.s3.amazonaws.com/batch%209/barcelona-boardwalk.jpg" alt="First slide"> -->
                        <!-- <div class="col-sm-12 col-xs-12 hidden-md hidden-lg" style="background: #DBDEE5;">
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/lms.png"></div>
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/mlg.png"></div>
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/abi.png"></div>
                        </div>
                        <div class="col-sm-12 col-xs-12 hidden-md hidden-lg" style="background: #DBDEE5;">
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/ppt.png"></div>
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/xapi.png"></div>
                            <div class="col-sm-4 col-xs-4" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/freeTrial/liveclass.png"></div>
                        </div> -->
                        <div class="col-sm-12 col-xs-12 hidden-md hidden-lg"
                            style="background: #DBDEE5;padding-top: 1%;height: 195px;align-items: center;display: flex;">
                            <img src="img/freeTrial/Updated_only_xAPI.png">
                        </div>
                        <h2>
                            <span>KEY FEATURES</span>
                        </h2>

                        <!-- </div>
                        </div> -->
                        <!-- /header-text -->
                    </div>
                    <div class="item">
                        <!-- <h2>
                            <span>Award Winning LMS for Enterprises</span>
                        </h2> -->
					<ul class="flex-container">
					  <li class="flex-item"><img src="img/clPage/honda.png" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/medley.png" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/APML-logo.png" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/elite_it.png" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/Maple Logo.png" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/hh_logo.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/fa_logo.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/quatrro.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/econz.webp" style="width: 100%;"></li>
					</ul>
					<ul class="flex-container">
					  <li class="flex-item"><img src="img/clPage/ethosh.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/tpl.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/kiranaKing.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/yoma.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/prowesoft.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/proxforce.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/acmegrade.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/edugreen.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/primus.webp" style="width: 100%;"></li>
					</ul>
					<ul class="flex-container">
					  <li class="flex-item"><img src="img/clPage/auxilo.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/spectrum.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/klay.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/walmartLogo.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_smile.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_team.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_tel.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_LFS.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_pres.webp" style="width: 100%;"></li>
					</ul>
					<ul class="flex-container">
					  <li class="flex-item"></li>
					  <li class="flex-item"></li>
					  <li class="flex-item"></li>
					  <li class="flex-item"><img src="img/clPage/client_child.webp" style="width: 100%;"></li>
					  <li class="flex-item"><img src="img/clPage/client_unnati.webp" style="width: 100%;"></li>
					  <li class="flex-item"></li>
					  <li class="flex-item"></li>
					  <li class="flex-item"></li>
					  <li class="flex-item"></li>
					</ul>
                      <!--   <div class="col-sm-12 col-xs-12 hidden-md hidden-lg"
                        style="background: #DBDEE5;height: 81px;padding-top: 2%;">
                        <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                            <img style="width: 100%;" src="img/clPage/primus.webp">
                        </div>
                        <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                            <img style="width: 100%;" src="img/clPage/auxilo.webp">
                        </div>
                        <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                            <img style="width: 100%;" src="img/clPage/spectrum.webp">
                        </div>
                        <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                            <img style="width: 100%;" src="img/clPage/klay.webp">
                        </div>
                    </div>
                        <div class="col-sm-12 col-xs-12 hidden-md hidden-lg"
                            style="background: #DBDEE5;height: 61px;padding-top: 0%;">
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/walmartLogo.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_tel.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_pres.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_smile.webp">
                            </div>
                        </div>
                        <div class="col-sm-12 col-xs-12 hidden-md hidden-lg"
                            style="background: #DBDEE5; height:87px;padding-top: 0%;">
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_unnati.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_team.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_child.webp">
                            </div>
                            <div class="col-sm-3 col-xs-3" style="text-align: center;padding: 2% 0 2% 0;">
                                <img style="width: 100%;" src="img/clPage/client_LFS.webp">
                            </div>
                        </div> -->
                        <h2>
                            <span>OUR CLIENTS</span>
                        </h2>

                        <!-- </div>
                        </div> -->
                        <!-- /header-text -->
                    </div>
                    <div class="item">
                        <!-- <h2>
                            <span>Award Winning LMS for Enterprises</span>
                        </h2> -->
                        <div class="col-sm-12 col-xs-12 hidden-md hidden-lg"
                            style="background: #DBDEE5;padding-top: 2%;padding-bottom: 1%;">
                            <img src="img/freeTrial/awardsMob.png">
                        </div>
                        <h2>
                            <span>AWARDS FOR PLAYABLO</span>
                        </h2>

                        <!-- </div>
                        </div> -->
                        <!-- /header-text -->
                    </div>
                </div>
                <!-- Controls -->
                <!-- <a class="left carousel-control" href="#carousel-example-generic" data-slide="prev">
                    <span class="glyphicon glyphicon-chevron-left"></span>
                </a>
                <a class="right carousel-control" href="#carousel-example-generic" data-slide="next">
                    <span class="glyphicon glyphicon-chevron-right"></span>
                </a> -->
            </div><!-- /carousel -->
        </div>
    </div>
    <!-- carousel ends  -->

    <button onclick="topFunction()" id="tothetopbutton" title="Go to top">Top</button>
    <!-- mobile signup section starts  -->

    <div class="hidden-lg hidden-md col-sm-12 col-xs-12 signUpContainer">
        
        <div class="pricingDiv">
            <div class="hidden-lg hidden-md col-sm-12 col-xs-12" style="font-family: Poppins-Regular;text-align: center;padding-top: 10%;font-size: 23px;letter-spacing: 0px;color: #1B1E6F;">
                <p>SIGN UP FOR A FREE TRIAL</p>
                <p style="font-size: 2vh;margin: -1% 0% 4% 0%;">No risk or obligation. No credit card required</p>
            </div>
            <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="font-family: Poppins-Regular;text-align: center;font-size: 23px;letter-spacing: 0px;color: #1B1E6F;padding-top: 1%;height: 17%;margin-bottom: 0%;">
                <p>SIGN UP FOR A FREE TRIAL</p>
                <p style="font-size: 2vh;margin: -1% 0% 2% 0%;">No risk or obligation. No credit card required</p>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">My Name is:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">

                    <input type="text" id="fNameMob" class="users" placeholder="Name">
                    <p class="errormsgFnameMob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please provide valid information.
                    </p>
                </div>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 0%;font-family: 'Poppins-Medium';    margin-bottom: -2%;">Send my Free Trial details at:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <input type="text" id="mailIdMob" class="users" name="email" placeholder="Work Email">

                    <p class="errormsgMailMob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please enter your official work email id to proceed with the Trial Setup
                    </p>
                </div>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';"></div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7 mobile-phone-code" style="margin-bottom: 1%;padding-right: 20px;
                padding-left: 9px;">
                    <!--<input class="users" id="phoneNoMob" placeholder="Work Phone" type="text" maxlength="10" pattern="/^([0|\+[0-9]{1,5})?([7-9][0-9]{9})$/" required="">-->
                    <input id="phoneNoMob" class="users" placeholder="Work Phone" maxlength="10" type="tel" name="phone" required style="width: 108%;"/>
                    <p class="errormsgPhone" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please provide valid information.
                    </p>
                    <p class="sucessstatuscapterra" style="display: none;"></p>
                </div>
                
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">I work in:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <!-- <input type="text" id="iName" class="users" name="iName" list="industryType"
                        placeholder="Select Industry">
                    <datalist id="industryType">
                        <option value="Manufacturing"></option>
                        <option value="Non-Profit"></option>
                        <option value="Retail"></option>
                        <option value="Training/Education"></option>
                        <option value="IT & ITES"></option>
                        <option value="Healthcare"></option>
                        <option value="Recruitment & Staffing"></option>
                        <option value="Consulting"></option>
                        <option value="Consumer & Packaged Goods"></option>
                        <option value="BFSI"></option>
                        <option value="Logistics"></option>
                        <option value="Others"></option>
                    </datalist> -->
                    <select id="iNameMob" class="users" name="iName" style="color: rgb(175, 177, 233); opacity: 1;">
                        <option id="indNameMob" value="" selected="" style="color: rgb(27, 30, 111);">Select Industry</option>
                        <option value="Manufacturing" style="color: rgb(27, 30, 111);">Manufacturing</option>
                        <option value="Non-Profit" style="color: rgb(27, 30, 111);">Non-Profit</option>
                        <option value="Retail" style="color: rgb(27, 30, 111);">Retail</option>
                        <option value="Training/Education" style="color: rgb(27, 30, 111);">Training/Education</option>
                        <option value="IT & ITES" style="color: rgb(27, 30, 111);">IT & ITES</option>
                        <option value="Healthcare" style="color: rgb(27, 30, 111);">Healthcare</option>
                        <option value="Recruitment & Staffing" style="color: rgb(27, 30, 111);">Recruitment & Staffing</option>
                        <option value="Consulting" style="color: rgb(27, 30, 111);">Consulting</option>
                        <option value="Consumer & Packaged Goods" style="color: rgb(27, 30, 111);">Consumer & Packaged Goods</option>
                        <option value="BFSI" style="color: rgb(27, 30, 111);">BFSI</option>
                        <option value="Logistics" style="color: rgb(27, 30, 111);">Logistics</option>
                        <option value="Others" style="color: rgb(27, 30, 111);">Others</option>
                    </select>
                    <p class="errormsgInameMob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select Industry
                    </p>
                    <p class="errormsgIname1Mob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select from given industries
                    </p>
                </div>
            </div>

            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">My role is:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <!-- <input type="text" id="rName" class="users" name="rName" list="role" placeholder="Your Role">
                    <datalist id="role">
                        <option value="CXO / Founder / Owner"></option>
                        <option value="Head / Manager HR"></option>
                        <option value="Head / Manager L&D"></option>
                        <option value="Head / Manager Head L&D"></option>
                        <option value="Executive HR / L&D"></option>
                        <option value="Learner / Student"></option>
                        <option value="Others"></option>
                    </datalist> -->
                    <select id="rNameMob" class="users" name="rNameMob" style="color: rgb(175, 177, 233); opacity: 1;">
                        <option id="urRoleMob" value="" selected="" style="color: rgb(27, 30, 111);">Your Role</option>
                                            <option value="CXO / Founder / Owner" style="color: rgb(27, 30, 111);">CXO / Founder / Owner</option>
                                            <option value="Head / Manager HR" style="color: rgb(27, 30, 111);">Head / Manager HR</option>
                                            <option value="Head / Manager L&D" style="color: rgb(27, 30, 111);">Head / Manager L&D</option>
                                            <!--<option value="Head / Manager Head L&D" style="color: rgb(27, 30, 111);">Head / Manager Head L&D</option>-->
                                            <option value="Executive HR / L&D" style="color: rgb(27, 30, 111);">Executive HR / L&D</option>
                                            <option value="Learner / Student" style="color: rgb(27, 30, 111);">Learner / Student</option>
                                            <option value="Others" style="color: rgb(27, 30, 111);">Others</option>
                                        </select>
                    <p class="errormsgRnameMob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select Your Role
                    </p>
                    <p class="errormsgRname1Mob" style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select from given Role
                    </p>
                </div>
            </div>
            <p class="errMsgMob" style="font-size: 15px;color: #b10909;font-family: Poppins-Medium; text-align: center;padding-top: 2%;">
            </p>
            <p class="succMsgMob" style="font-size: 15px;color: #54A17E;font-family: Poppins-Medium; text-align: center;padding-top: 2%;">
            </p>
            <div style="display: inline-flex;align-items: flex-start;margin-top: 5%;padding: 0% 0% 0% 45%;">
                <input type="checkbox" id="mob-contentservice-checkbox" value="I'm also looking for content development services">
            <label style="margin-left: 5%;font-size: 12px;">I'm also looking for Content development services</label><br>
            </div>
            <div class="btnContainerMob col-lg-12 col-md-12  col-sm-12 col-xs-12"><button id="startthetrailbuttonmob">Start my Trial</button>
            </div>
            <div class="descriptionPMob col-lg-12 col-md-12 col-sm-12 col-xs-12">By submitting this form, I agree to
                the <a target="_blank" href="tandc.html" style="color: #337ab7 !important;text-decoration: underline;">terms
                    of service</a>
                and <a href="privacy.html" target="_blank" style="color: #337ab7 !important;text-decoration: underline;">privacy
                    policy</a>.
                PlayAblo will use any of the
                data <br class="hidden-lg hidden-md"> provided hereunder in accordance <br class="hidden-lg hidden-md">
                with the Privacy Policy.
            </div>
        </div>
    </div>

    <!-- mobile signup section ends -->

    <!-- <div class="col-lg-1 col-md-1 col-sm-12 col-xs-12"></div> -->
    <div class="col-sm-12 col-xs-12 col-lg-12 col-md-12 row">
        <div class="col-sm-12 col-xs-12 col-lg-6 col-md-6 row">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12 signUpContainer" id="sidebar" style="margin-top: -10px;margin-left: 10px;">
        <div>
            <!--<div class="col-md-5 col-lg-5 hidden-sm hidden-xs" style="margin-top: 0%">
                    <a href="index.html" target="_blank">
                    <img src="img/freeTrial/logo.svg" class="logo_mob1" style="width: 100%;">
                    </a>
                </div>-->
    </div>
        <div class="pricingDiv hidden-sm hidden-xs">
            <div class="hidden-lg hidden-md col-sm-12 col-xs-12"
                style="font-family: Poppins-Regular;text-align: center;padding-top: 10%;font-size: 23px;letter-spacing: 0px;color: #1B1E6F;">
                <p>SIGN UP FOR A FREE TRIAL</p>
                <p style="font-size: 11px;margin: -1% 0% 4% 0%;">No risk or obligation. No credit card required</p>
            </div>
            <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
                style="font-family: Poppins-Regular;text-align: center;font-size: 23px;letter-spacing: 0px;color: #1B1E6F;padding-top: 1%;height: 17%;margin-bottom: 0%;">
                <p>SIGN UP FOR A FREE TRIAL</p>
                <p style="font-size: 11px;margin: -1% 0% 2% 0%;">No risk or obligation. No credit card required</p>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">My Name is:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">

                    <input type="text" id="fName" class="users" placeholder="Name">
                    <p class="errormsgFname"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please provide valid information.
                    </p>
                </div>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 0%;font-family: 'Poppins-Medium';    margin-bottom: -2%;">Send my Free Trial details at:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <input type="text" id="mailId" class="users" name="email" placeholder="Work Email">

                    <p class="errormsgMail"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please enter your official work email id to proceed with the Trial Setup
                    </p>
                </div>
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';"></div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7 phone_code" style="margin-bottom: 1%; padding-left: 5px; padding-right: 23px;">
                   <!--<input class="users" id="phoneNo" placeholder="Work Phone" type="text" maxlength="10"
                        pattern="/^([0|\+[0-9]{1,5})?([7-9][0-9]{9})$/" required>--> 
                        <input id="phone" class="users" placeholder="Work Phone" maxlength="10" type="tel" name="phone" required style="width: 108%;"/>
                    <p class="errormsgPhone"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Please provide valid information.
                    </p>
                    <p class="sucessstatuscapterra" style="display: none;"></p>
                </div>
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';"></div>
                
                
            </div>
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">I work in:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <!-- <input type="text" id="iName" class="users" name="iName" list="industryType"
                        placeholder="Select Industry">
                    <datalist id="industryType">
                        <option value="Manufacturing"></option>
                        <option value="Non-Profit"></option>
                        <option value="Retail"></option>
                        <option value="Training/Education"></option>
                        <option value="IT & ITES"></option>
                        <option value="Healthcare"></option>
                        <option value="Recruitment & Staffing"></option>
                        <option value="Consulting"></option>
                        <option value="Consumer & Packaged Goods"></option>
                        <option value="BFSI"></option>
                        <option value="Logistics"></option>
                        <option value="Others"></option>
                    </datalist> -->
                    <select id="iName" class="users" name="iName" style="margin-top: -10px;">
                        <option id="indName" value="" selected>Select Industry</option>
                        <option value="Manufacturing">Manufacturing</option>
                        <option value="Non-Profit">Non-Profit</option>
                        <option value="Retail">Retail</option>
                        <option value="Training/Education">Training/Education</option>
                        <option value="IT & ITES">IT & ITES</option>
                        <option value="Healthcare">Healthcare</option>
                        <option value="Recruitment & Staffing">Recruitment & Staffing</option>
                        <option value="Consulting">Consulting</option>
                        <option value="Consumer & Packaged Goods">Consumer & Packaged Goods</option>
                        <option value="BFSI">BFSI</option>
                        <option value="Logistics">Logistics</option>
                        <option value="Others">Others</option>
                    </select>
                    <p class="errormsgIname"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select Industry
                    </p>
                    <p class="errormsgIname1"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select from given industries
                    </p>
                </div>
            </div>

            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';">My role is:</div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <!-- <input type="text" id="rName" class="users" name="rName" list="role" placeholder="Your Role">
                    <datalist id="role">
                        <option value="CXO / Founder / Owner"></option>
                        <option value="Head / Manager HR"></option>
                        <option value="Head / Manager L&D"></option>
                        <option value="Head / Manager Head L&D"></option>
                        <option value="Executive HR / L&D"></option>
                        <option value="Learner / Student"></option>
                        <option value="Others"></option>
                    </datalist> -->
                    <select id="rName" class="users" name="rName">
                        <option id="urRole" value="" selected>Your Role</option>
                                            <option value="CXO / Founder / Owner">CXO / Founder / Owner</option>
                                            <option value="Head / Manager HR">Head / Manager HR</option>
                                            <option value="Head / Manager L&D">Head / Manager L&D</option>
                                            <!--<option value="Head / Manager Head L&D">Head / Manager Head L&D</option>-->
                                            <option value="Executive HR / L&D">Executive HR / L&D</option>
                                            <option value="Learner / Student">Learner / Student</option>
                                            <option value="Others">Others</option>
                                        </select>
                    <p class="errormsgRname"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select Your Role
                    </p>
                    <p class="errormsgRname1"
                        style="font-size: 1.9vh;color: #ee2828;font-family: Poppins-Medium;text-align: center;padding-top: 2%;">
                        Select from given Role
                    </p>
                </div>
            </div>
            <p class="errMsg"
                style="font-size: 15px;color: #b10909;font-family: Poppins-Medium; text-align: center;padding-top: 2%;">
            </p>
            <p class="succMsg"
                style="font-size: 15px;color: #54A17E;font-family: Poppins-Medium; text-align: center;padding-top: 2%;">
            </p>
            <p class="forminncorrect" style="position: absolute; width: 7%; top: 29%; left: 90%;font-size: 27px; font-weight: 900; color: #fff; background-color: #e80000;text-align: center;display: none;">!</p>
            <p class="form_correct"><img src="img/freeTrial/green-checkmark-icon.png" style="position: absolute; width: 7%; top: 29%; left: 90%;display: none;"></p>
            
            
            <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="min-height: 5%;">
                <div class="col-lg-4 col-md-4 col-sm-5 col-xs-5" style="margin-bottom: 1%;padding: 1%;font-family: 'Poppins-Medium';"></div>
                <div class="col-lg-8 col-md-8 col-sm-7 col-xs-7" style="margin-bottom: 1%;">
                    <!-- <input type="text" id="rName" class="users" name="rName" list="role" placeholder="Your Role">
                    <datalist id="role">
                        <option value="CXO / Founder / Owner"></option>
                        <option value="Head / Manager HR"></option>
                        <option value="Head / Manager L&D"></option>
                        <option value="Head / Manager Head L&D"></option>
                        <option value="Executive HR / L&D"></option>
                        <option value="Learner / Student"></option>
                        <option value="Others"></option>
                    </datalist> -->
                    <div style="display: inline-flex;align-items: flex-start;margin-top: 5%;">
                        <input type="checkbox" id="contentservice-checkbox" value="I'm also looking for content development services">
                    <label style="margin-left: 5%;font-size: 12px;">I'm also looking for Content development services</label><br>
                    </div>
                    
                   
                </div>
            </div>
            
            
            
            
            
            
           
            <div class="btnContainer col-lg-12 col-md-12  col-sm-12 col-xs-12"><button id="startthetrailbutton" class="g-recaptcha" 
                data-sitekey="6LfzmBMnAAAAAE5TXBsminFHn3_9PmIIs2piy-su" 
                data-callback='onSubmit' 
                data-action='submit'>Start my Trial</button>
            </div>
            <div class="descriptionP col-lg-12 col-md-12 col-sm-12 col-xs-12">I submit this form and agree to the <a target="_blank" href="tandc.html"
                    style="color: #337ab7 !important;text-decoration: underline;">terms
                    of service</a>
                and <a href="privacy.html" target="_blank"
                    style="color: #337ab7 !important;text-decoration: underline;">privacy
                    policy</a>.
                PlayAblo will use any of the
                data <br class="hidden-lg hidden-md"> provided here under the  <br class="hidden-lg hidden-md">
                Privacy Policy.
            </div>
        </div>
        <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="font-family: Poppins-Light;text-align: center;margin-top: 1%;font-size: 26px;letter-spacing: 2.45px;">
            
            <hr class="col-lg-2 col-md-2 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
            <p class="col-lg-6 col-md-5 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
                Trusted By
    
            </p>
            <hr class="col-lg-2 col-md-2 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
            <!-- <p>
                <img src=" img/clPage/mldLine.png" style="margin-top: -2%;">
            </p> -->
            </div>
            <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 26px;letter-spacing: 2.45px;display: flex;">
            
                
                <p>
                    <img src="img/freeTrial/trustby1.jpeg" style="margin-top: -30%;width: 100%;">
                </p>
                <p>
                    <img src="img/freeTrial/trustby2.jpeg" style="margin-top: -30%;width: 100%;">
                </p>
                <p>
                    <img src="img/freeTrial/trustby3.jpeg" style="margin-top: -30%;width: 100%;">
                </p>
                <p>
                    <img src="img/freeTrial/trustby4.jpeg" style="margin-top: -30%;width: 100%;">
                </p>
                <a href="#someclients" id="view-more-customer">More <i class="fas fa-arrow-right"></i></a>
                </div>
                
                
    
    
    <!-- </div> -->
    
        
            </div>
    </div>
    <div class="col-lg-6 col-md-6 hidden-sm hidden-xs" style="padding: 0%; float: right;">
       
        <div class="col-lg-12 col-md-12 co-sm-12 col-xs-12 videoContainer" style="padding: 0;">
            <div class="youtube-player" data-id="PIqB4ughbFY" data-related="0" data-control="1" data-info="1"
                data-fullscreen="1"
                style="border-bottom: 27px solid #0B0B4A;border-left: 31px solid #0B0B4A;border-top: 24px solid #0B0B4A;border-right: 31px solid #0B0B4A;width:100%;display: block; position: relative;cursor: pointer;max-height:360px;height:407px; overflow:hidden;padding-bottom:56.25%;margin:0 auto">
                <iframe src="//www.youtube.com/embed/PIqB4ughbFY?autoplay=0&autohide=2&border=0&wmode=opaque&enablejsapi=1&rel=0&controls=1&showinfo=1" frameborder="0" id="youtube-iframe" style="width: 100%; height: 100%; position: absolute; top: 0; left: 0;" allowfullscreen=""></iframe>
            </div>
        </div>
        <div>
        </div>
    <!-- </div> -->
    <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
        style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 23px;letter-spacing: 2.45px;">
        <p class="col-lg-2 col-md-2 col-sm-1 col-xs-1"></p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <p class="col-lg-4 col-md-4 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
            KEY FEATURES

        </p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
    </div>
    <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="
padding: 0% 0% 0% 0%;
">
         <!--<div class="col-lg-10 col-md-10 hidden-sm hidden-xs"> -->
        <div class="col-lg-1 col-md-1" style="text-align: center;padding: 2% 0 2% 0;"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/lms.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/mlg.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/abi.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/ppt.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/xapi.png"></div>
                </div>
        <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="padding: 0% 0% 0% 0%;margin-top: -3%;">
        <div class="col-lg-1 col-md-1" style="text-align: center;padding: 2% 0 2% 0;"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/liveclass.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/selfSubs.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/e_certifications.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/ratings.png"></div>
        <div class="col-lg-2 col-md-2" style="text-align: center;padding: 2% 0 2% 0;"><img style="width: 100%;"
                src="img/freeTrial/mailNoti.png"></div>
    </div>
    <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="padding: 0% 4% 0% 6%;text-align: center;font-family: 'Poppins-Medium';">
        <h5><a href="playablo-lms-features.html" target="_blank" style="color: #337ab7 !important;text-decoration: underline;">Learn more...</a></h5>
    </div>

    
    <!-- key features -->
    <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
        style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 23px;letter-spacing: 2.45px;">
        <p class="col-lg-1 col-md-1 col-sm-1 col-xs-1"></p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <p class="col-lg-6 col-md-6 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
            LMS KEY FEATURES DELIVERED BY PLAYABLO

        </p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
    </div>
    <div class="row" style="display: flex;">
        <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
            <div class="hidden-sm hidden-xs">
                <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                    Integration & SSO Support</h2>
            </div>
            <div class="hidden-lg hidden-md">
                <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                    Integration & SSO Support</h2>
            </div>

        <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
            <p style="font-family: Poppins-Regular;font-size: 15px;">The corporate LMS software, PlayAblo, integrates easily into your existing landscape of internal systems. Our LMS portal also supports Single Sign-On making the integration extremely easy and fast.</p>
        </div>
        


</div>
<div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
        <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
            Rapid Implementation</h2>
    </div>
    <div class="hidden-lg hidden-md">
        <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
            Rapid Implementation</h2>
    </div>
        <p style="font-family: Poppins-Regular;font-size: 15px;">(Cloud-based SaaS Solution)</p>
<div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">PlayAblo is a free cloud LMS and SaaS solution that ensures rapid implementation, lower operating costs, increased scalability, and easy integration. New releases and upgrades are straightforward to propagate.</p>
</div>



</div>
    </div> 
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Any Device - Any OS - Anytime</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Any Device - Any OS - Anytime</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Access PlayAblo's learning content from any device, including desktops, smartphones, tablets, and iPads. The training modules are optimized to fit most screen sizes.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
        Learn at Your Place, Your Pace</h2>
    </div>
    <div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
        Learn at Your Place, Your Pace</h2>
    </div>
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">Built for Micro-learning, PlayAblo is the best LMS platform that allows learners the option to learn at their own pace and place. Progress as much as possible and continue from where you left off whenever possible!</p>
    </div>
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Learn Offline</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Learn Offline</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">No internet? No problem! Simply ask your employees to use PlayAblo's offline option and download content to learn without going online. How do you track progress? Just sync when you can.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
        Build eLearning Content 70% Faster!</h2>
    </div>
    <div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
        Build eLearning Content 70% Faster!</h2>
    </div>
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">Our CMS module is everything you need to create mobile-ready eLearning content 60-70% faster than traditional SCORM-based content creation.</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Integrated LMS and CMS</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Integrated LMS and CMS</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">The integrated LMS and CMS feature enables corporates to manage learners, keep track of their progress and performance, and create + distribute new learning materials -- all from one platform!</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
        LIVE Classes</h2>
    </div>
    <div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
        LIVE Classes</h2>
    </div>
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">LIVE Classes are integral to the Blended Learning approach. PlayAblo, one of the top enterprise LMS solutions, comes pre-integrated with G-Meet, lending a real-time replication of the traditional classroom experience. Need another LIVE platform integrated? Just ask!</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                xAPI and SCORM Compliant</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                xAPI and SCORM Compliant</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">PlayAblo's SCORM and xAPI compliant platform lets you add eLearning content that is inherently responsive for all devices and allows data collection about your learners' wide range of experiences within your training.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
        Best-in-class Dashboards</h2>
    </div>
    <div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
        Best-in-class Dashboards</h2>
    </div>
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">PlayAblo's dashboards give a real-time view of your learners' progress regarding aggregated usage, progress, and performance view.</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Self-subscribe to Courses</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Self-subscribe to Courses</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">PlayAblo lets learners search for non-mandatory courses and subscribe to additional programs per their job needs without any external intervention.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; float: right; width: 48%;">
    <div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
        Auto-subscribe to Courses</h2>
    </div>
    <div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
        Auto-subscribe to Courses</h2>
    </div>
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
    <p style="font-family: Poppins-Regular;font-size: 15px;">Depending upon the learner's role and department, specific courses are mandatory or needed for compliance. You can set up courses for Auto subscriptions based on rules, including recurring subscriptions for compliance.</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Create Mobile-friendly Courses Directly from PPTs</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Create Mobile-friendly Courses Directly from PPTs</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">PlayAblo lets you create mobile-friendly eLearning courses without needing fancy content creation software. Just use our PPT template and click to convert them into beautiful mobile learning modules!</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
   style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 23px;letter-spacing: 2.45px;">
   <p class="col-lg-1 col-md-1 col-sm-1 col-xs-1"></p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
   <p class="col-lg-6 col-md-6 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
    READ-MADE TRAINING COURSES. FREE!

   </p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
</div>
<div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Business Communication</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Business Communication</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Our business communication courses aim to raise awareness of and encourage good information-sharing habits inside and outside enterprises. We've compiled the essentials of business communication because it's a field where one can quickly get lost, making it simple for anyone to interact with people from different backgrounds and in various settings.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Code of Conduct</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Code of Conduct</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Maintaining one's moral compass can be difficult in the business world, so it's essential to understand how to resolve moral conundrums. A code of conduct serves as a definitive manual for how personnel should conduct themselves while carrying out their duties. 

            A company's code of conduct outlines the values, norms, and ethical and moral standards employees must uphold. As a result, creating a culture of compliance becomes vital, boosting employee morale and expediting career advancement. Our courses will teach your workers how to uphold professional conduct standards in various job situations.
            </p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Communication Effectiveness</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Communication Effectiveness</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Communication is undoubtedly at the top of the list in most studies that identify the abilities required in the workplace, whether for successful teamwork, conflict resolution, leadership, or skills for the future workplace. 

            Effective workplace communication is essential and determines whether a business succeeds or fails. Help your employees learn the fundamentals of communicationâlistening, speaking, writing, and reading with PlayAblo. Your workers will learn techniques to apply them successfully and repair difficult workplace dialogues.
            </p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                POSH in the Office</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                POSH in the Office</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Life security and individual freedom, as well as equality, are guaranteed under our country's constitution. The consequences of sexual harassment at work are significant, both psychologically and financially. Every company is accountable for stopping sexual harassment and ensuring a safe environment. 

            Additionally, every employee must contribute to fostering a hostile-free work environment. The laws governing sexual harassment, the appeals procedure, and the precautions that any company must take to avoid sexual harassment at work will all be covered in the POSH courses.
            </p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Cybersecurity</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Cybersecurity</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Employees in any firm must understand their duties for securing their networks and avoiding any threats as businesses adjust to proper remote working methods. Our cybersecurity courses inform workers on the different forms of cyberattacks, how to avert them, how to secure their networks, and the best practices to adhere to when using their personal devices and home networks for work.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Teamwork and Collaboration</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Teamwork and Collaboration</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Successful teams are the foundation of organizations. The factors that tie together the team's shared values, common goals, and shared mindset influence the success of the team. While shared goals and ideologies bring a team together, disagreements between team members can damage a team. Teach your employees how to create effective teams, manage conflicts to strengthen them, and use effective communication techniques to pursue excellence in teams.</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="row" style="display: flex;">
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Time Management</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Time Management</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Making time to carry out your plans will increase their effectiveness. It becomes vital to juggle our plans in our personal areas and workplaces. But if we don't have enough time to manage everything all at once, we can let some plans go awry. Self-management is a big part of time management. Our e-Learning course teaches staffers how to divide their time between professional and personal commitments, discover and remove time-wasting barriers, and comprehend productivity-boosting techniques.</p>
    </div>
    
    
    
    </div>
    <div class="col-lg-5 col-md-5 col-sm-12 col-xs-12" style="margin-top: 20px; background-color:#fff; padding: 20px; margin-right: 10px; width: 48%;">
        <div class="hidden-sm hidden-xs">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: -8px 0px 0px 0px;">
                Sales and Communication Development</h2>
        </div>
        <div class="hidden-lg hidden-md">
            <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: -8px 0px 0px 0px;">
                Sales and Communication Development</h2>
        </div>
    
    <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 5%;">
        <p style="font-family: Poppins-Regular;font-size: 15px;">Any business's most valuable resource is its clientele. Sales representatives are the people who make connections with every consumer from the outset by learning about their needs, earning their confidence, identifying the best services and products for them, and making sure that value is provided. You can improve your employees' sales toolkit and help them become more effective sellers by taking one of our programs on sales skills.</p>
    </div>
    
    
    
    </div>
   </div>
   <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
   style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 23px;letter-spacing: 2.45px; margin-bottom: 5%;">
   <p class="col-lg-1 col-md-1 col-sm-1 col-xs-1"></p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
   <p class="col-lg-6 col-md-6 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
    COMMON EMPLOYEE TRAINING CHALLENGES ADDRESSED BY PLAYABLO

   </p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Inconsistency Brought on by Non-Standardized Learning</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Inconsistency Brought on by Non-Standardized Learning</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">Consistency and getting the same learning results from the same learning tools are the main concerns in employee learning and development, especially in large corporate organizations' LMS training systems. Unfortunately, if you rely on external trainers for learning, it is difficult to confirm that instructional strategies and domain knowledge are always compatible. A clear curriculum can be established to lessen this circumstance.

    <br><br>Since most of your workplace education will be online, implementing standardized training modules is something to consider. For instance, all courses can have the same time constraints and predetermined learning goals.
    </p>
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Convenient and Comfortable Business Learning in a Constrained Time Frame</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Convenient and Comfortable Business Learning in a Constrained Time Frame</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">The amount of time is limited, and there are many things to do. However, when a company needs to remain competitive, every person is expected to work as hard as possible. Implementing a culture of continuous learning in a workplace where time is limited is, therefore, one of the most critical corporate concerns of the present.

    <br><br>We've established that on-the-job training should be a need, not a luxury. You can use technology to increase the flexibility and accessibility of workplace learning so that you aren't overwhelmed by the fast-paced nature of a digital workplace. Create mobile learning opportunities on an LMS for on-the-go learning for a simple and user-friendly method to deal with workplace learning difficulties.
    </p>
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Dealing with a Multigenerational Workplace</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Dealing with a Multigenerational Workplace</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">It is entirely conceivable to have team members from various generations, which is yet another issue with workplace learning that the industry must deal with during LMS development. The millennial generation's comfort level with online learning and growth has been widely discussed.

    <br><br>They respond well to learning strategies like gamification and microlearning. Therefore, this technique is advantageous for them. Senior personnel must, however, be considered. As with different cultures, different generations have distinct learning styles.
    </p>
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Automating the Management of Learning Challenges</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Automating the Management of Learning Challenges</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">We've grown accustomed to automation in other consumer technology domains, so it stands to reason that we'll soon see it in learning solutions as well. We anticipate receiving learning recommendations from the company's learning platform akin to those offered by Netflix and Amazon.

    <br><br>Other features include automated and self-service access to new learning content to make finding the next lesson to study more accessible. According to 31% of L&D professionals, automation technology may be leveraged to deliver this educational and training material to organizations, easing their struggles with workplace learning.
    </p>
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Individualized Instruction for Better Understanding</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Individualized Instruction for Better Understanding</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">Employees are increasingly seeking employment prospects that include training, and they demand that the training be pertinent, delivered in the format of their choice, and customized to their learning style. Employees look forward to a thorough learning strategy tailored to their unique learning styles, allowing them to progress professionally while improving their job performance.

    <br><br>A contemporary and effective LMS enables team leaders to tailor their learning models to the needs of their workforce. Such an LMS results in an improved learning experience that keeps their workforce valuable, in-demand, and relevant while also assisting the growing business by addressing workplace learning challenges.
    </p>
</div>
<div class="hidden-sm hidden-xs">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 22px !important;margin: 20px 0px 0px 0px;">
        Learning Models to Deal With Low Employee Engagement</h2>
</div>
<div class="hidden-lg hidden-md">
    <h2 style="font-family: Poppins-Regular !important;color: #101010;font-size: 19px !important;margin: 0px 0px 0px 0px;">
        Learning Models to Deal With Low Employee Engagement</h2>
</div>

<div class="normal-box-text" style="  display:flex;justify-content: center;align-items: center;padding: 0;margin-top: 0%;">
<p style="font-family: Poppins-Regular;font-size: 15px;">The time employees have available for training is decreasing; thus, 36% of L&D professionals advise looking for innovative ways to boost participants' interest in carefully thought-out training programs.

    <br><br>Some workers choose not to interact with the trainers while they are teaching. The learner's incapacity primarily causes this behavior to understand the learning objectives or recognize the relevance of the instruction to them. The delivery approach could be tedious and repetitive, adding to the enormous mountain of workplace learning difficulties.
    
    <br><br>It's becoming more common for L&D to use the strategies used by marketing and communications professionals when considering the techniques they use to foster this involvement. This strategy employs marketing techniques in two ways:
    
    <br><br>Content for employee learning is well-organized, automated with recommendations, and consumer-inspired to encourage engagement. Email and other forms of internal communication should be used to inform employees about changes to learning models.
    
    <br><br>Some of the aforementioned workplace learning difficulties have long been a source of irritation for L&D. You can overcome these obstacles, though, if you are consistent, logical, flexible, and constantly involve your employees in the process.
    
    <br><br>And a top-notch LMS like PlayAblo can assist in the implementation of the majority of the options. Don't forget to contact our specialists at PlayAblo for all things learning if you're seeking an effective LMS that will guide you through the workplace learning difficulties in your organization for improved company success.
    </p>
</div>
<div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
   style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 23px;letter-spacing: 2.45px; margin-bottom: 5%;">
   <p class="col-lg-1 col-md-1 col-sm-1 col-xs-1"></p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
   <p class="col-lg-6 col-md-6 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
    PlayAblo KPIs

   </p>
   <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
</div>
<div class="normal-box-text" style="margin-top: 5%;">
    <ul>
        <li style="font-weight:700;">LMS usage </li>
        <li style="font-weight:700;">Learner progress</li>
        <li style="font-weight:700;">Learner performance</li>
        </ul>
    <p style="font-family: Poppins-Regular;font-size: 15px;">When you use a platform like PlayAblo, your dashboard provides you with a comprehensive view of the abovementioned KPIs. You receive an overall estimate of the hours per week spent using your LMS platform. You also receive a breakdown of learner completion statistics, such as how many of your staff finished the course. How many people have not yet begun a particular session? And how many are now studying a particular module?

        <br><br>Finally, PlayAblo, a top LMS for businesses, continuously provides performance ratings. You may always check on a student's progress. You can track a batch of 30 learners' progress, for instance, if they are on the 40th day of their training plan. What was their previous grade before the course? How have they changed after finishing the course? And after participating in a specific program, what are their scores?
    </p>
    <p style="font-family: Poppins-Regular;font-size: 15px;" id="someclients"><br><br>By providing two views, PlayAblo further enables you to analyze a particular module thoroughly. You can even look further into the aggregate overview to see details about individual students' usage, development, and performance. And a thorough breakdown of each module will assist facilitators in 
        </p>
       
    </div>

    
   
    <!-- clints section -->
    <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
        style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 26px;letter-spacing: 2.45px;">
        <p class="col-lg-2 col-md-2 col-sm-1 col-xs-1"></p>
        <hr class="col-lg-1col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <p class="col-lg-4 col-md-4 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
            SOME OF OUR CLIENTS

        </p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <!-- <p>
            <img src=" img/clPage/mldLine.png" style="margin-top: -2%;">
        </p> -->
		</div>
		 <!-- 29 Logos Slider starts -->
              
                  
                  
                  
         <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="padding-bottom: 1%; margin-bottom: 5%;margin-top: 3%;">
            <section class="customer-logos slider">
                
                <div class="slide">
                    <img
                      class="sld-img sld-img-19"
                      src="img/clPage/auxilo.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-19">Auxilo Finserve</div>
                  </div>
                  </div>
                <div class="slide">
                  <img
                    class="sld-img sld-img-2"
                    src="img/clPage/medley.png"
                  />
                  <div class="nameinslider">
                    <div class="client-name client-name-2">Medley Pharmaceuticals</div></div>
                  
                </div>
                <div class="slide">
                    <img
                      class="sld-img sld-img-5"
                      src="img/clPage/Maple Logo.png"
                    />
                    <div class="nameinslider">
                      <div class="client-name client-name-5">Maple Technologies</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-21"
                      src="img/clPage/klay.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-21">Klay Schools</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-22"
                      src="img/clPage/walmartLogo.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-22">Walmart Vriddhi</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-1"
                      src="img/clPage/honda.png"
                    /><div class="nameinslider">
                      <div class="client-name client-name-1">Honda India Power <br>Products Limited</div>
                  </div>
                    </div>
                    <div class="slide">
                        <img
                          class="sld-img sld-img-13"
                          src="img/clPage/yoma.webp"
                        />
                        <div class="nameinslider">
                            <div class="client-name client-name-13">YOMA Business Solutions</div>
                        </div>
                       
                      </div>
        
                <div class="slide">
                  <img
                    class="sld-img sld-img-3"
                    src="img/clPage/APML-logo.png"
                  />
                  <div class="nameinslider">
                    <div class="client-name client-name-3">APML - Agarwal <br>Packers & Movers</div>
                  </div>
                  
                </div>
                <div class="slide">
                    <img
                      class="sld-img sld-img-14"
                      src="img/clPage/prowesoft.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-14">Prowess Software</div>
                    </div>
                   
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-15"
                      src="img/clPage/proxforce.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-15">ProXForce Software</div>
                  </div>
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-20"
                      src="img/clPage/spectrum.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-20">Spectrum Consultants</div>
                    </div>
    
                    
                  </div>
                  <div class="slide">
                    <img
                        class="sld-img sld-img-16"
                        src="img/clPage/acmegrade.webp"
                      />
                    <div class="nameinslider">
                        <div class="client-name client-name-16">Acmegrade</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-9"
                      src="img/clPage/econz.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-9">Econz IT</div>
                    </div>
                    
                  </div>
                <div class="slide">
                  <img
                    class="sld-img sld-img-4"
                    src="img/clPage/elite_it.png"
                  />
                  <div class="nameinslider">
                    <div class="client-name client-name-4">Elite IT Recruitment</div>
                  </div>
                  
                </div>
                <div class="slide">
                    <img
                      class="sld-img sld-img-17"
                      src="img/clPage/edugreen.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-17">Edugreen Education</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-7"
                      src="img/clPage/fa_logo.webp"
                    />
                    <div class="nameinslider">
                      <div class="client-name client-name-7">FieldAssist</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-8"
                      src="img/clPage/quatrro.webp"
                    />
                    <div class="nameinslider">
                      <div class="client-name client-name-8">Quatrro Mortgage</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-11"
                      src="img/clPage/tpl.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-11">Pinch Lifestyle</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-18"
                      src="img/clPage/primus.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-18">Primus Partners</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-10"
                      src="img/clPage/ethosh.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-10">Ethosh Designs</div>
                    </div>
                   
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-12"
                      src="img/clPage/kiranaKing.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-12">Kirana King Retail</div>
                    </div>
                    
                  </div>
                <div class="slide">
                  <img
                    class="sld-img sld-img-6"
                    src="img/clPage/hh_logo.webp"
                  />
                  <div class="nameinslider">
                    <div class="client-name client-name-6">HotelHub</div>
                  </div>
                  
                </div>
                
                
                <div class="slide">
                    <img
                      class="sld-img sld-img-23"
                      src="img/clPage/client_smile.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-23">Smile Foundation</div>
                  </div>
                  </div>
                  
                  <div class="slide">
                    <img
                      class="sld-img sld-img-24"
                      src="img/clPage/client_unnati.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-24">SGBS Unnati <br>Foundation</div>
                    </div>
                    
                  </div>
                  
                  <div class="slide">
                    <img
                      class="sld-img sld-img-28"
                      src="img/clPage/client_child.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-28">ChildFund India</div>
                  </div>
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-26"
                      src="img/clPage/client_LFS.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-26">Lifestyle International</div>
                  </div>
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-27"
                      src="img/clPage/client_pres.webp"
                    />
                    <div class="nameinslider">
    
                    <div class="client-name client-name-27">Presidency College <br>of Hotel Management</div>
                  </div>
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-25"
                      src="img/clPage/client_tel.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-25">Turbo Energy Limited</div>
                    </div>
                   
                  </div>
                  <div class="slide">
                    <img
                      class="sld-img sld-img-29"
                      src="img/clPage/client_team.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-29">Teamware - Quantum <br>Leap Consulting</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-30"
                      src="img/clPage/Pathkind Labs.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-30">Pathkind Labs</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-31"
                      src="img/clPage/Chhattisgarh Agricon Samiti.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-31">Chhattisgarh <br/>Agricon Samiti</div>
                    </div>
                    
                  </div>
    
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-32"
                      src="img/clPage/Vestige.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-32">Vestige</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-33"
                      src="img/clPage/Gupshup.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-33">Gupshup</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-34"
                      src="img/clPage/Talent Quotient.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-34">Talent Quotient</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-35"
                      src="img/clPage/Empaxis.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-35">Empaxis</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-36"
                      src="img/clPage/Shriram Properties.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-36">Shriram Properties</div>
                    </div>
                    
                  </div>
                  <div class="slide">
                    <img loading="lazy"
                      class="sld-img sld-img-37"
                      src="img/clPage/Bloom Hotels Group.webp"
                    />
                    <div class="nameinslider">
                        <div class="client-name client-name-37">Bloom Hotels Group</div>
                    </div>
                    
                  </div>
                  
                  
                  
                  
                  
                  
                  
                  
                  
                  
              </section>
        </div>
    
      <!--logos Slider Ends-->
      <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 26px;letter-spacing: 2.45px;">
        
        <hr class="col-lg-1col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <p class="col-lg-8 col-md-8 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
            JOIN OUR COMMUNITY OF HAPPY CUSTOMERS

        </p>
        <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        <!-- <p>
            <img src=" img/clPage/mldLine.png" style="margin-top: -2%;">
        </p> -->
		</div>
        <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
            <div class="testimonials-slideshow-container" style="display: flex; height: 400px; align-items: center;">

                <div class="testimonials-mySlides" style="display: block;">
                  <q class="testiominiqal-text">Auxilo Finserve has decided to engage with PlayAblo as our Learning Management Service provider due to the simplicity of the platform. Auxilo is a fairly new organization and is in the process of establishing our Learning Management for our growing employee base. We are located across India and need an LMS that is easy for users to access with minimum IT or Administrator support.  

                    PlayAblo provides the flexibility for us to create, implement, manage and drive our Learning programs and initiatives internally with minimum technical dependency.</q>
                  <p class="testimonials-author">- Linus Mascarenhas, Manager, L&D</p>
                  <p class="testimonials-author-position">Auxilo Finserve</p>
                </div>
                
                <div class="testimonials-mySlides" style="display: none;">
                  <q class="testiominiqal-text">The overall experience with the product is great and we receive expert, instantaneous support from the tech team. The content management team is par excellence. PlayAbloâs top leadership is very attentive and responsive to customer feedback and plans product roadmaps based on client inputs.</q>
                  <p class="testimonials-author">- Santosh R. , Technology  Lead</p>
                  <p class="testimonials-author-position">Walmart Vriddhi</p>
                </div>
                
                <div class="testimonials-mySlides" style="display: none;">
                  <q class="testiominiqal-text">I liked the LMS for the ease of usage and prompt support. It has helped my field colleagues get used to cloud based LMS as I have plans to expose them to advanced content.</q>
                  <p class="testimonials-author">- Arshad Q, DGM - Training</p>
                  <p class="testimonials-author-position">Medley Pharmaceuticals</p>
                </div>

                <div class="testimonials-mySlides" style="display: none;">
                    <q class="testiominiqal-text">Overall Satisfied with the ease of access and usage</q>
                    <p class="testimonials-author">- UdayKiran K. , L&D</p>
                    <p class="testimonials-author-position">Prowessoft</p>
                  </div>
                  <div class="testimonials-mySlides" style="display: none;">
                    <q class="testiominiqal-text">As Klay moved to virtual learning our search for a right partner to support our learning journey fructified in our association with PlayAblo. Their interactive learning app with gamified features provided us with the right platform for content upload, delivery and the experience focuses on being child friendly and user friendly.</q>
                    <p class="testimonials-author">- Arshleen Kalra, Head Academics & Service Delivery</p>
                    <p class="testimonials-author-position">KLAY Schools</p>
                  </div>
                
                <a class="testimonials-prev" onclick="plusSlides(-1)">â®</a>
                <a class="testimonials-next" onclick="plusSlides(1)">â¯</a>
                
                </div>
                
                <div class="testimonials-dot-container">
                  <span class="testimonials-dot active" onclick="currentSlide(1)"></span> 
                  <span class="testimonials-dot" onclick="currentSlide(2)"></span> 
                  <span class="testimonials-dot" onclick="currentSlide(3)"></span>
                  <span class="testimonials-dot" onclick="currentSlide(4)"></span>
                  <span class="testimonials-dot" onclick="currentSlide(5)"></span> 
                </div>
        </div>
        <!--<div data-include="logos.html"></div>-->
        <!-- Award section -->
        <div class="col-lg-12 col-md-12 hidden-sm hidden-xs"
            style="font-family: Poppins-Light;text-align: center;margin-top: 5%;font-size: 26px;letter-spacing: 2.45px;margin-left: -5%;">
            <p class="col-lg-2 col-md-2 col-sm-1 col-xs-1"></p>
            <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
            <p class="col-lg-6 col-md-6 col-sm-6 col-xs-6" style="font-size: 20px;margin-top: 1%;">
                AWARDS FOR PLAYABLO

            </p>
            <hr class="col-lg-1 col-md-1 col-sm-1 col-xs-1" style="background-color: #6E6E6E;">
        </div>
        <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="
padding: 2% 0%;
">
            <img src="img/freeTrial/awards.png" style="
width: 100%;
">
        </div>
        <div class="col-lg-12 col-md-12 hidden-sm hidden-xs" style="
    padding: 2% 7%;
">
            <div class="col-lg-4 col-md-4 hidden-sm hidden-xs" style="
    padding: 0px 1%;
">
                <hr style="
    border-top: 3px solid #ea750e;
">
            </div>
            <div class="col-lg-4 col-md-4 hidden-sm hidden-xs" style="
    padding: 0 1%;
">
                <hr style="
    border-top: 3px solid #1d9d6d;
">
            </div>
            <div class="col-lg-4 col-md-4 hidden-sm hidden-xs" style="
    padding: 0 1%;
">
                <hr style="
    border-top: 3px solid #cf4233;
">
            </div>
        </div>
        <div class="hidden-lg hidden-md" style="
        padding: 5% 7%;
        width: 100%;
        text-align: center;
        /* margin-top: 5%; */
    "><a target="_blank" href="https://www.playablo.com/img/iso_certificate.webp"><img alt="playAblo" style="width: 17%;background: #4385f4;border-radius: 25%;" src="img/iso.webp"></a></div>
    </div>
   
    </div>
            <!-- footer section -->
            <div data-include="footer.html"></div>
            <!-- <footer style="background: none;padding: 0% 2% 0% 0%;margin-left: 2%;background: #E2E2E2 0% 0% no-repeat padding-box;" class="col-lg-12 col-md-12 hidden-sm hidden-xs">
                <div class="hidden-sm hidden-xs divFooter footerTab col-md-5 col-lg-5 col-sm-12 col-xs-12" style="
             padding: 0;
             width: 7%;
             float: left;
        ">
        <a target="_blank" href="https://www.playablo.com/img/iso_certificate.webp"><img alt="playAblo" style="width: 75%;background: #4385f4;border-radius: 25%; margin: 0% 11%;" src="img/iso.webp"></a></div>
                <div class="divFooter footerTab col-md-5 col-lg-5 col-sm-12 col-xs-12" style="
        letter-spacing: 0.45px;
        /*padding-left: 25px;*/
        width: 35%;
             float: left;
    ">
                    <a class="aFooter" href="aboutUs.html"> ABOUT US </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="partnersPlayablo.html"> PARTNERS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="awards.html"> AWARDS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="mediaPlayablo.html"> MEDIA </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="careers.html" class="aFooter"> CAREERS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="tandc.html" class="aFooter">
                         TERMS & CONDITIONS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="privacy.html" class="aFooter"> PRIVACY POLICY </a>
    
                </div>
                <div class="allrsrvHome col-md-4 col-lg-4 col-sm-12 col-xs-12" style="display: block;text-align: center;height: auto;width: 38%;border-left: 2px solid #d1d1d1;">
                    Email: <a href="mailto:CorporateLearning@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">CorporateLearning@playablo.com
                    </a>
                    <b style="color:#838383!important; font-weight: bolder;">|</b>
                    Mob: +91-97408 78833<br>
        <span><b>Address:</b> No 3/2,Aishwarya Complex, 3rd & 4th Floor, Bellandur Gate, Ambalipura, Sarjapur Main Road, Bangalore- 560103.</span>
                </div>
    
                <div class="allrsrvHome col-md-3 col-lg-3 col-sm-12 col-xs-12" style="display: block;width: 20%;">â¸ <span class="copyRightYear">2021</span>
                    Playablo. All Rights Reserved
    
                </div>
            </footer> -->
            <!-- for mobile -->
          <!--  <footer style="background: none;padding: 0% 6% 21% 6%;margin-left: 2%;"
                class="col-sm-12 col-xs-12 hidden-lg hidden-md">
                <div class="divFooter footerTab col-sm-12 col-xs-12" style="
        letter-spacing: 0.45px;
        /*padding-left: 25px;*/
    ">
                    <a class="aFooter" href="aboutUs.html"> ABOUT US </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="partnersPlayablo.html"> PARTNERS </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="awards.html"> AWARDS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a class="aFooter" href="mediaPlayablo.html"> MEDIA </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="careers.html" class="aFooter"> CAREERS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="tandc.html" class="aFooter">
                         TERMS & CONDITIONS </a>
                    <a style="color:#838383!important; font-weight: bolder;"> | </a>
                    <a href="privacy.html" class="aFooter"> PRIVACY POLICY </a>
    
                </div>
                <div class="allrsrvHome col-sm-12 col-xs-12" style="display: block;text-align: center;height: auto;">
                    Email: <a
                        href="mailto:CorporateLearning@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">CorporateLearning@playablo.com
                    </a>
                    <b style="color:#838383!important; font-weight: bolder;">|</b><br />
                    Mob: +91-97408 78833<br/>
                    <span><b>Address:</b> No 3/2,Aishwarya Complex, 3rd & 4th Floor, Bellandur Gate, Ambalipura, Sarjapur Main Road, Bangalore- 560103.</span>
                </div>
                <div class="allrsrvHom col-sm-12 col-xs-12" style="display: block;">â¸ <span class="copyRightYear"></span>
                    Playablo. All Rights Reserved
    
                </div>
                <div id="output"></div>
            </footer>
        <div id="output"></div>-->
        
       
       <!--
        <footer style="background-color: rgb(220 220 220 / 88%) !important;padding: 0% 2% 0% 0%;padding-left: 2%;" class="col-lg-12 col-md-12 hidden-sm hidden-xs">
            <div class="hidden-sm hidden-xs divFooter footerTab col-md-5 col-lg-5 col-sm-12 col-xs-12" style="
         padding: 0;
         width: 7%;
    "><a target="_blank" href="https://www.goodfirms.co/software/playablo-lms"><img alt="playAblo" style="width: 50%;" src="https://assets.goodfirms.co/badges/color-badge/learning-management-system-software.svg"></a>
    <a target="_blank" href="https://www.playablo.com/img/iso_certificate.webp"><img alt="playAblo" style="width: 41%;background: #4385f4;border-radius: 25%;" src="img/iso.webp"></a></div>
            <div class="divFooter footerTab col-md-5 col-lg-5 col-sm-12 col-xs-12" style="
    letter-spacing: 0.45px;
    /*padding-left: 25px;*/
    width: 35%;
">
                <a class="aFooter" href="aboutUs.html"> ABOUT US </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a class="aFooter" href="partnersPlayablo.html"> PARTNERS </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a class="aFooter" href="awards.html"> AWARDS </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a class="aFooter" href="mediaPlayablo.html"> MEDIA </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a href="careers.html" class="aFooter"> CAREERS </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a href="tandc.html" class="aFooter">
                     TERMS & CONDITIONS </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a href="privacy.html" class="aFooter"> PRIVACY POLICY </a>
                <a style="color:#838383!important; font-weight: bolder;"> | </a>
                <a href="abac-policy.pdf" target="_blank" class="aFooter" style="text-transform: uppercase;">Anti Bribery and Anti Corruption Policy</a>

            </div>
            <div class="allrsrvHome col-md-4 col-lg-4 col-sm-12 col-xs-12" style="display: block;text-align: center;height: auto;width: 38%;border-left: 2px solid #d1d1d1;">
                Email: <a href="mailto:CorporateLearning@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">CorporateLearning@playablo.com
                </a>
                <b style="color:#838383!important; font-weight: bolder;">|</b>
                Mob: +91-97408 78833<br>
    <span><b>Address:</b> No 3/2,Aishwarya Complex, 3rd & 4th Floor, Bellandur Gate, Ambalipura, Sarjapur Main Road, Bangalore- 560103.</span>
            </div>

            <div class="allrsrvHome col-md-3 col-lg-3 col-sm-12 col-xs-12" style="display: block;width: 20%;">â¸ <span class="copyRightYear">2023</span>
                Playablo. All Rights Reserved

            </div>
        </footer>
       --> 
      
       <footer class="py-5" style="padding-top: 5%;background-color: transparent !important;position: relative;" id="footer">
        <div style="background-color: #000 !important;">
            <div class="row footertoprows" style="padding: 5% 0% 0% 2%;" >
                <div class="col-6 col-md-2 mb-3" style="width: max-content;">
                  <h5 class="heading-footer">Who are we</h5>
                  <ul class="nav flex-column contact-foterinfo">
                    <li class="nav-item mb-2"><a href="awards.html" class="nav-link p-0 text-muted">Awards</a></li>
                    <li class="nav-item mb-2"><a href="mediaPlayablo.html" class="nav-link p-0 text-muted">Media</a></li>
                    <li class="nav-item mb-2"><a href="careers.html" class="nav-link p-0 text-muted">Careers</a></li>
                    <li class="nav-item mb-2"><a href="aboutUs.html" class="nav-link p-0 text-muted">About Us</a></li>
                    <li class="nav-item mb-2"><a href="workplace-learning-ebook.html" class="nav-link p-0 text-muted">Free eBook</a></li>
                  </ul>
                </div>
          
                <div class="col-6 col-md-2 mb-3" style="width: max-content;">
                  <h5 class="heading-footer">About PlayAblo LMS</h5>
                  <ul class="nav flex-column contact-foterinfo">
                    <li class="nav-item mb-2"><a href="index.html" class="nav-link p-0 text-muted">Home</a></li>
                    <li class="nav-item mb-2"><a href="playablo-lms-features.html" class="nav-link p-0 text-muted">Features</a></li>
                    <li class="nav-item mb-2"><a href="pricing.html" class="nav-link p-0 text-muted">Pricing</a></li>
                    <li class="nav-item mb-2"><a href="courses.html" class="nav-link p-0 text-muted">Readymade Courses</a></li>
                    <li class="nav-item mb-2"><a href="https://www.playablo.com/CorporateLearning/Blog/" class="nav-link p-0 text-muted">Playablo Blog</a></li>
                  </ul>
                </div>
          
                <div class="col-6 col-md-2 mb-3" style="width: max-content;">
                  <h5 class="heading-footer">Workplace Learning</h5>
                  <ul class="nav flex-column contact-foterinfo">
                    <li class="nav-item mb-2"><a href="learning-management-system.html" class="nav-link p-0 text-muted">What is LMS?</a></li>
                    <li class="nav-item mb-2"><a href="corporate-training-platform.html" class="nav-link p-0 text-muted">Learning lifecycle</a></li>
                    <li class="nav-item mb-2"><a href="elearning-management-system.html" class="nav-link p-0 text-muted">elearning content</a></li>
                    <li class="nav-item mb-2"><a href="what-is-learning-path-and-how-to-create.html" class="nav-link p-0 text-muted">Learning Path</a></li>
                    <li class="nav-item mb-2"><a href="playablo-free-trial.html" class="nav-link p-0 text-muted">Try playablo for free</a></li>
                  </ul>
                </div>
          
                <div class="col-md-4 offset-md-1 mb-3 contact-footer-row">
                    <h4 class="heading-footer2">Contact Us</h4>
                    <table style="width:100%">
                        <tr>
                          <td class="contoury-name-loc">India</td>
                          <td style="padding-left: 5%;">
                            <div class="info-rows" style="display: inline-flex;align-items: flex-start;">
                                <img src="img/footer/location.png" style="width: 12%;padding-top:1.5%;"><p class="contact-foterinfo" style="padding-left: 4.5%;margin-bottom: 0px;">No 3/2,Aishwarya Complex<br/> 
                                    Sarjapur Main Road<br/>
                                    Bangalore- 560103
                                    </p>
                            </div>
                            <br>
                            <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                                <img src="img/footer/email.png" style="width: 20%;padding: 0% 2.5% 0% 2%;"><p class="contact-foterinfo" style="padding-left: 2%;margin-bottom: 0px;"><a href="mailto:indiasales@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">indiasales@playablo.com
    
                                </a></p>
                            </div><br/>
                            <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                              <img src="img/footer/phone.png" style="width: 20%;"><p class="contact-foterinfo" style="padding-left: 2%;margin-bottom: 0px;">+91.97408.78833</p>
                          </div>
                            
                           
                          </td>
                        
                        </tr>
                        <tr>
                            <td class="contoury-name-loc" style="padding-top: 5%;">US</td>
                            <td style="padding-left: 5%;padding-top: 5%;">
                              <div class="info-rows" style="display: inline-flex;align-items: flex-start;">
                                  <img src="img/footer/location.png" style="width: 15%;padding-top:1.5%;"><p class="contact-foterinfo" style="padding-left: 4.5%;margin-bottom: 0px;">770 Armstrong Blvd<br/>
    
                                    Coppell, TX 75019
                                      </p>
                              </div>
                              <br>
                              <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                                  <img src="img/footer/email.png" style="width: 20%;padding: 0% 2.5% 0% 2%;"><p class="contact-foterinfo" style="padding-left: 2%;margin-bottom: 0px;"><a href="mailto:usasales@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">usasales@playablo.com
      
                                  </a></p>
                              </div><br/>
                              <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                                <img src="img/footer/phone.png" style="width: 21%;"><p class="contact-foterinfo" style="padding-left: 2%;line-height: 1.7em;margin-bottom: 0px;">+1.646.312.7242</p>
                            </div>
                             
                            </td>
                          
                          </tr>
                          <tr>
                            <td class="contoury-name-loc" style="padding-top: 5%;">UK</td>
                            <td style="padding-left: 5%;padding-top: 5%;">
                              <div class="info-rows" style="display: inline-flex;align-items: flex-start;">
                                  <img src="img/footer/location.png" style="width: 18%;padding-top:1.5%;"><p class="contact-foterinfo" style="padding-left: 4.5%;margin-bottom: 0px;">2 Finchley Way<br/>
                                    London N31AG
                                    
                                      </p>
                              </div>
                              <br>
                              <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                                  <img src="img/footer/email.png" style="width: 20%;padding: 0% 2.5% 0% 2%;"><p class="contact-foterinfo" style="padding-left: 2%;margin-bottom: 0px;"><a href="mailto:uksales@playablo.com?cc=playablocl@playablo.com&subject=Your%20request%20for%20PlayAblo%20Corporate%20Learning%20Demo">uksales@playablo.com
      
                                  </a></p>
                              </div>
                              
                             
                            </td>
                          
                          </tr>
                      </table>
            
                   <!--
                    <div class="info-rows" style="display: inline-flex;align-items: center;padding: 3% 0%;">
                        <img src="img/footer/phone.png" style="width: 20%;"><p class="contact-foterinfo" style="padding-left: 2%;">+91-97408 78833</p>
                    </div>
                   --> 
                    
                  </div>
              </div>
          
              <div class="fotercopyright" style="padding:2% 7% 2% 7%">
                  <div class="divFooter footerTab col-md-5 col-lg-5 col-sm-12 col-xs-12 footer-logos" >
                      <a target="_blank" href="https://www.goodfirms.co/software/playablo-lms">
                          <img alt="playAblo" class="footerlogo1" src="https://assets.goodfirms.co/badges/color-badge/learning-management-system-software.svg"></a>
             <a target="_blank" href="https://www.playablo.com/img/iso_certificate.webp">
              <img alt="playAblo" class="footerlogo2" src="img/iso.webp"></a></div>
                  <p class="footer-copyright-text">Â© 2023 Playablo. All Rights Reserved.</p>
                <ul class="ulSocialMediaIndex link-privacy-footer" style="margin: 0px;padding-right: 0%;">
          
                  <!-- <li><a href="https://apps.apple.com/in/app/playablo-neo-for-schools/id1470029016"
                          target="_blank"><img src="img/lp/solutions/userLogin.webp" width="21"></a>
                  </li> -->
                  <li><a href="tandc.html" class="leftFooterlink"> TERMS & CONDITIONS </a></li>
          
                  <li><a href="privacy.html" class="leftFooterlink"> PRIVACY POLICY </a></li>
          
                  
              </ul>
              </div>
        </div>
       
      </footer>
        <script>
            $(function () {
                    $(document).scroll(function () {
                        var $nav = $(".navbar-fixed-top");
                        $nav.toggleClass('scrolled', $(this).scrollTop() > $nav.height());
                    });
                });
                $('body').scroll(function () {
                    // $('.navbar').addClass('scrolled');
                    var scroll = $('body').scrollTop();

                    if (scroll >= 5) {
                        $(".navbar").addClass("scrolled");
                    } else {
                        $(".navbar").removeClass("scrolled");
                    }

                });
            // Get the button
let mybutton = document.getElementById("tothetopbutton");

// When the user scrolls down 20px from the top of the document, show the button
window.onscroll = function() {scrollFunction()};

function scrollFunction() {
  if (document.body.scrollTop > 0 || document.documentElement.scrollTop > 0) {
    mybutton.style.display = "block";
  } else {
    mybutton.style.display = "none";
  }
}

// When the user clicks on the button, scroll to the top of the document
function topFunction() {
  document.body.scrollTop = 0;
  document.documentElement.scrollTop = 0;
}
function getIp(callback) {
 fetch('https://ipinfo.io/json?token=c3d38d4fc98d79', { headers: { 'Accept': 'application/json' }})
   .then((resp) => resp.json())
   .catch(() => {
     return {
       country: 'us',
     };
   })
   .then((resp) => callback(resp.country));
}
            const phoneInputField = document.querySelector("#phone");
            const phoneInput = window.intlTelInput(phoneInputField, {
                separateDialCode: true,
                initialCountry: "auto",
 geoIpLookup: getIp,
  hiddenInput: "full",
              utilsScript:
                "https://cdnjs.cloudflare.com/ajax/libs/intl-tel-input/17.0.8/js/utils.js",
            });
           
            const phonemobInputField = document.querySelector("#phoneNoMob");
            const phonemobInput = window.intlTelInput(phonemobInputField, {
                separateDialCode: true,
                initialCountry: "auto",
 geoIpLookup: getIp,
  hiddenInput: "full",
              utilsScript:
                "https://cdnjs.cloudflare.com/ajax/libs/intl-tel-input/17.0.8/js/utils.js",
            });
            
          </script>
          <script type="text/javascript">
                
            function trackingListener() {
            var capterra_vkey = 'f7b897d307188247b3b7e55cfa951e26',
            capterra_vid = '2192906',
            ct = document.createElement('img');
            ct.src = 'https://ct.capterra.com/capterra_tracker.gif?vid='
            + capterra_vid + '&vkey=' + capterra_vkey;
            document.body.appendChild(ct);
            };
            /*var buttonId = 'startthetrailbutton'; // Change this
            var button = document.getElementById(buttonId);
            button.addEventListener(
            'click',
            trackingListener
            );*/

            
           
            
            </script>
            
        <script type="text/javascript">
        window.onload=function(){
            $('#rName').css('color','#AFB1E9').css('opacity',1);
            $('#iName').css('color','#AFB1E9').css('opacity',1);
            $('option').css('color','#1B1E6F');
        }
            $(document).ready(function () {
                        
                var today = new Date()
                var year = today.getFullYear()
                // document.write(year)
                $('.copyRightYear').html(year);

                $('li').mouseover(function () {
                    $(this).find('hr').css('visibility', 'visible');
                });
                $('li').mouseleave(function () {
                    if (!$(this).hasClass('liMoz3')) {
                        $(this).find('hr').css('visibility', 'hidden');
                    }

                });
                $('.tabBtn').click(function () {
                    $('.tabBtn').removeClass('activeTab');
                    $(this).addClass('activeTab');
                })
                $("input[name=city]").val("India");
                function validateEmailPhoneNumber(phoneNumber) {
                    var re = /^([0|\+[0-9]{1,5})?([7-9][0-9]{9})$/;
                    return re.test(String(phoneNumber).toLowerCase());
                }
                 
                $('#rName').change(function(){
                    if($('#urRole').prop('selected') == true){
                        $(this).css('color','#AFB1E9').css('opacity',1);
                    }
                    else{
                        $(this).css('color','#1B1E6F');
                        $('option').css('color','#1B1E6F');
                    }
                })
                $('#iName').change(function(){
                    if($('#indName').prop('selected') == true){
                        $(this).css('color','#AFB1E9').css('opacity',1);
                    }
                    else{
                        $(this).css('color','#1B1E6F');
                        $('option').css('color','#1B1E6F');
                    }
                })
                
              $('.btnContainer button').click(function () {
                    var erroMessage1 = "Your message has been received. We will contact you shortly";
                    var firstName = $('#fName').val();
                    // var lastName = $('#lName').val();
                    // var conpanyName = $('#cName').val();
                    var industryName = $('#iName').val();
                    var roleName = $('#rName').val();
                    var countryName = $('#countryCode').val();
                    var userPhone = $('.phone_code .iti__selected-dial-code').text()+"-"+$('#phone').val();
                    var phonecheck = $('#phone').val();
                    var empNom = $('#empNo').val();
                    var contentcheckbox = $('#contentservice-checkbox').val();
                    var emailblockReg =
                        /^([\w-\.]+@(?!yahoo.com)(?!hotmail.com)(?!aol.com)(?!hotmail.co.uk)(?!hotmail.fr)(?!msn.com)(?!yahoo.fr)(?!wanadoo.fr)(?!orange.fr)(?!comcast.net)(?!yahoo.co.uk)(?!yahoo.com.br)(?!yahoo.co.in)(?!live.com)(?!rediffmail.com)(?!free.fr)(?!gmx.de)(?!web.de)(?!yandex.ru)(?!ymail.com)(?!libero.it)(?!outlook.com)(?!uol.com.br)(?!bol.com.br)(?!mail.ru)(?!cox.net)(?!hotmail.it)(?!sbcglobal.net)(?!sfr.fr)(?!live.fr)(?!verizon.net)(?!live.co.uk)(?!email.com)(?!googlemail.com)(?!yahoo.es)(?!ig.com.br)(?!live.nl)(?!bigpond.com)(?!terra.com.br)(?!yahoo.it)(?!neuf.fr)(?!yahoo.de)(?!alice.it)(?!rocketmail.com)(?!att.net)(?!laposte.net)(?!facebook.com)(?!bellsouth.net)(?!yahoo.in)(?!hotmail.es)(?!charter.net)(?!yahoo.ca)(?!yahoo.com.au)(?!rambler.ru)(?!hotmail.de)(?!tiscali.it)(?!shaw.ca)(?!yahoo.co.jp)(?!sky.com)(?!earthlink.net)(?!optonline.net)(?!freenet.de)(?!t-online.de)(?!aliceadsl.fr)(?!virgilio.it)(?!home.nl)(?!qq.com)(?!telenet.be)(?!me.com)(?!yahoo.com.ar)(?!tiscali.co.uk)(?!yahoo.com.mx)(?!voila.fr)(?!gmx.net)(?!mail.com)(?!planet.nl)(?!tin.it)(?!live.it)(?!ntlworld.com)(?!arcor.de)(?!yahoo.co.id)(?!frontiernet.net)(?!hetnet.nl)(?!live.com.au)(?!yahoo.com.sg)(?!zonnet.nl)(?!club-internet.fr)(?!juno.com)(?!optusnet.com.au)(?!blueyonder.co.uk)(?!bluewin.ch)(?!skynet.be)(?!sympatico.ca)(?!windstream.net)(?!mac.com)(?!centurytel.net)(?!chello.nl)(?!live.ca)(?!aim.com)(?!bigpond.net.au)(?!gmail.co)(?!yahoo.co)(?!icloud.com)([\w-]+\.)+[\w-]{2,4})?$/;
                    // var emailblockReg = /^([\w-\.]+@([\w-]+\.)+[\w-]{2,4})?$/;
                    var email = $("#mailId").val();
                    if (firstName == "") {
                        $(".errormsgFname").show().fadeOut(2500);
                        $(".forminncorrect").show().fadeOut(2500);
                        return false;
                    } else if (!emailblockReg.test(email.toLowerCase()) || email == "") {
                        $(".errormsgMail").show().fadeOut(2500);
                        $(".forminncorrect").show().fadeOut(2500);
                        return false;
                    }
                    else if (phonecheck.trim() == "") {
                        $(".errormsgPhone").show().fadeOut(2500);
                        $(".forminncorrect").show().fadeOut(2500);
                        return false;
                    }
                    
                    //  else if (countryName == "") {
                    //     $(".errormsgCountry").show().fadeOut(2500);
                    //     return false;
                    // }
                    else if (industryName == "") {
                        $(".errormsgIname").show().fadeOut(2500);
                        $(".forminncorrect").show().fadeOut(2500);
                        return false;
                    }
                    else if (industryName != "Manufacturing" && industryName != "Non-Profit" && industryName != "Retail" &&
                        industryName != "Training/Education" && industryName != "IT & ITES" && industryName != "Healthcare" &&
                        industryName != "Recruitment & Staffing" && industryName != "Consulting" && industryName != "Consumer & Packaged Goods" &&
                        industryName != "BFSI" && industryName != "Logistics" && industryName != "Others") {
                        $(".errormsgIname1").show().fadeOut(2500);
                        $(".forminncorrect").show().fadeOut(2500);
                        return false;
                    }
                    
                    else if (roleName == "") {
                        $(".errormsgRname").show().fadeOut(2500);
                        $(".forminncorrect").show()
                        return false;
                    }
                    else if (roleName != "CXO / Founder / Owner" && roleName != "Head / Manager HR" && roleName != "Head / Manager L&D" &&
                        roleName != "Head / Manager Head L&D" && roleName != "Executive HR / L&D" && roleName != "Learner / Student" &&
                        roleName != "Others") {
                        $(".errormsgRname1").show().fadeOut(2500);
                        $(".forminncorrect").show()
                        return false;
                    }

                    else {
                        $(".form_correct").show()
                        $('.btnContainer button').attr('disabled', 'true');
                        $('.btnContainer button').css('background', '#bfbfbf');
                        var name = firstName;
                        var countryCode = "Country - " + countryName;
                        var schoolName = "Industry - " + industryName;
                        // var message1 = " Country - " + countryName + ", Industry - " + industryName + ", Number of Employees - " + empNom + ", Phone - " + userPhone;
                        
                        if( $('#contentservice-checkbox').is(':checked') ){
                        var message1 = "Name - " + firstName + "<br>work email - " + email + "<br>Industry: " + industryName + "<br>work phone - " + userPhone + "<br>Role - " + roleName + "<br> " + contentcheckbox;
                    }
                    else{
                        var message1 = "Name - " + firstName + "<br>work email - " + email + "<br>Industry: " + industryName + "<br>work phone - " + userPhone + "<br>Role - " + roleName;
                    }


                        var date = "2020-10-14";
                        var timeString = "2:25 PM";
                        // var erroMessage1 = "Message has been sent successfully!!";
                        // $("#errMsg").text("valid");
                        $('body').css('cursor', 'url(images/loader.gif),auto');
                        //$(".errMsg").html("");
                        const emailcont = '';
                        
                            const datamail = { EmailId: email, Subject: 'Your request for PlayAblo Free Trial', datetime: date, time: timeString, Name: name, Type: 'CL', Message: message1, cityname: countryCode, schoolname: schoolName, phone: userPhone}
                       
                        
                        console.log(datamail)

                        $.ajax({

                            url: "PHPMailer-master/sendMailCL.php",
                            data: { 'postData': datamail },
                            type: "POST",
                            success: function (response) {
                                var data = JSON.parse(response);
                                if (data.data == 'Success') {
                                   
                
                                    trackingListener();
                                    $(".ajaxloading").hide();
                                    $(".succMsg").html(erroMessage1);
                                    $('body').css('cursor', 'auto');
                                    $(".errormsgMail").hide();
                                    $('#fName').val("");
                                    $('#iName').val("");
                                    $('#countryCode').val("");
                                    $('#phoneNo').val("");
                                    $('#empNo').val("");
                                    $("input[name=email]").val("");
                                    $('.btnContainer button').attr('disabled', 'false');
                                    $('.btnContainer button').css('background', '#EA7421 0% 0% no-repeat padding-box');
                                    $('.sucessstatuscapterra p').append('success');

                                    setTimeout(function () {
                                        return gtag_report_conversion('https://www.playablo.com/playablo-free-trial.html')
                                    }, 1000);


                                }
                                else {
                                    // alert("fail;")
                                    $(".ajaxloading").hide();
                                }

                            }
                        })
                    }
                    
              });


            //   Mobile signup function starts here
            $('#rNameMob').change(function(){
                    if($('#urRoleMob').prop('selected') == true){
                        $(this).css('color','#AFB1E9').css('opacity',1);
                    }
                    else{
                        $(this).css('color','#1B1E6F');
                        $('option').css('color','#1B1E6F');
                    }
                })
                $('#iNameMob').change(function(){
                    if($('#indNameMob').prop('selected') == true){
                        $(this).css('color','#AFB1E9').css('opacity',1);
                    }
                    else{
                        $(this).css('color','#1B1E6F');
                        $('option').css('color','#1B1E6F');
                    }
                })
              $('.btnContainerMob button').click(function () {
                    var erroMessage1 = "Your message has been received. We will contact you shortly";
                    var firstName = $('#fNameMob').val();
                    // var lastName = $('#lName').val();
                    // var conpanyName = $('#cName').val();
                    var industryName = $('#iNameMob').val();
                    var roleName = $('#rNameMob').val();
                    var countryName = $('#countryCodeMob').val();
                    var contentcheckbox = $('#mob-contentservice-checkbox').val();
                    var userPhone = $('.mobile-phone-code .iti__selected-dial-code').text()+"-"+$('#phoneNoMob').val();
                    var empNom = $('#empNoMob').val();
                    var emailblockReg =
                        /^([\w-\.]+@(?!yahoo.com)(?!hotmail.com)(?!aol.com)(?!hotmail.co.uk)(?!hotmail.fr)(?!msn.com)(?!yahoo.fr)(?!wanadoo.fr)(?!orange.fr)(?!comcast.net)(?!yahoo.co.uk)(?!yahoo.com.br)(?!yahoo.co.in)(?!live.com)(?!rediffmail.com)(?!free.fr)(?!gmx.de)(?!web.de)(?!yandex.ru)(?!ymail.com)(?!libero.it)(?!outlook.com)(?!uol.com.br)(?!bol.com.br)(?!mail.ru)(?!cox.net)(?!hotmail.it)(?!sbcglobal.net)(?!sfr.fr)(?!live.fr)(?!verizon.net)(?!live.co.uk)(?!googlemail.com)(?!yahoo.es)(?!ig.com.br)(?!live.nl)(?!bigpond.com)(?!terra.com.br)(?!yahoo.it)(?!neuf.fr)(?!yahoo.de)(?!alice.it)(?!rocketmail.com)(?!att.net)(?!laposte.net)(?!facebook.com)(?!bellsouth.net)(?!yahoo.in)(?!hotmail.es)(?!charter.net)(?!yahoo.ca)(?!yahoo.com.au)(?!rambler.ru)(?!hotmail.de)(?!tiscali.it)(?!shaw.ca)(?!yahoo.co.jp)(?!sky.com)(?!earthlink.net)(?!optonline.net)(?!freenet.de)(?!t-online.de)(?!aliceadsl.fr)(?!virgilio.it)(?!home.nl)(?!qq.com)(?!telenet.be)(?!me.com)(?!yahoo.com.ar)(?!tiscali.co.uk)(?!yahoo.com.mx)(?!voila.fr)(?!gmx.net)(?!mail.com)(?!planet.nl)(?!tin.it)(?!live.it)(?!ntlworld.com)(?!arcor.de)(?!yahoo.co.id)(?!frontiernet.net)(?!hetnet.nl)(?!live.com.au)(?!yahoo.com.sg)(?!zonnet.nl)(?!club-internet.fr)(?!juno.com)(?!optusnet.com.au)(?!blueyonder.co.uk)(?!bluewin.ch)(?!skynet.be)(?!sympatico.ca)(?!windstream.net)(?!mac.com)(?!centurytel.net)(?!chello.nl)(?!live.ca)(?!email.com)(?!aim.com)(?!bigpond.net.au)(?!gmail.co)(?!yahoo.co)(?!iCloud.com)([\w-]+\.)+[\w-]{2,4})?$/;
                    // var emailblockReg = /^([\w-\.]+@([\w-]+\.)+[\w-]{2,4})?$/;
                    var email = $("#mailIdMob").val();
                    if (firstName == "") {
                        $(".errormsgFnameMob").show().fadeOut(2500);
                        return false;
                    } else if (!emailblockReg.test(email.toLowerCase()) || email == "") {
                        $(".errormsgMailMob").show();
                        return false;
                    }
                    //  else if (countryName == "") {
                    //     $(".errormsgCountry").show().fadeOut(2500);
                    //     return false;
                    // }
                    else if (industryName == "") {
                        $(".errormsgInameMob").show().fadeOut(2500);
                        return false;
                    }
                    else if (industryName != "Manufacturing" && industryName != "Non-Profit" && industryName != "Retail" &&
                        industryName != "Training/Education" && industryName != "IT & ITES" && industryName != "Healthcare" &&
                        industryName != "Recruitment & Staffing" && industryName != "Consulting" && industryName != "Consumer & Packaged Goods" &&
                        industryName != "BFSI" && industryName != "Logistics" && industryName != "Others") {
                        $(".errormsgIname1Mob").show().fadeOut(2500);
                        return false;
                    }
                    else if (userPhone.trim() == "") {
                        $(".errormsgPhoneMob").show().fadeOut(2500);
                        return false;
                    }
                    else if (roleName == "") {
                        $(".errormsgRnameMob").show().fadeOut(2500);
                        return false;
                    }
                    else if (roleName != "CXO / Founder / Owner" && roleName != "Head / Manager HR" && roleName != "Head / Manager L&D" &&
                        roleName != "Head / Manager Head L&D" && roleName != "Executive HR / L&D" && roleName != "Learner / Student" &&
                        roleName != "Others") {
                        $(".errormsgRname1Mob").show().fadeOut(2500);
                        return false;
                    }

                    else {
                        $('.btnContainerMob button').attr('disabled', 'true');
                        $('.btnContainerMob button').css('background', '#bfbfbf');
                        var name = firstName;
                        var countryCode = "Country - " + countryName;
                        var schoolName = "Industry - " + industryName;
                        // var message1 = " Country - " + countryName + ", Industry - " + industryName + ", Number of Employees - " + empNom + ", Phone - " + userPhone;
                        if( $('#mob-contentservice-checkbox').is(':checked') ){
                        var message1 = "Name - " + firstName + "<br>work email - " + email + "<br>Industry: " + industryName + "<br>work phone - " + userPhone + "<br>Role - " + roleName + "<br> " + contentcheckbox;
                    }
                    else{
                        var message1 = "Name - " + firstName + "<br>work email - " + email + "<br>Industry: " + industryName + "<br>work phone - " + userPhone + "<br>Role - " + roleName;
                    }

                        var date = "2020-10-14";
                        var timeString = "2:25 PM";
                        // var erroMessage1 = "Message has been sent successfully!!";
                        // $("#errMsg").text("valid");
                        $('body').css('cursor', 'url(images/loader.gif),auto');
                        //$(".errMsg").html("");
                        const emailcont = '';

                        const datamail = { EmailId: email, Subject: 'Your request for PlayAblo Free Trial', datetime: date, time: timeString, Name: name, Type: 'CL', Message: message1, cityname: countryCode, schoolname: schoolName, phone: userPhone }
                        console.log(datamail)
                        
                        $.ajax({

                            url: "PHPMailer-master/sendMailCL.php",
                            data: { 'postData': datamail },
                            type: "POST",
                            success: function (response) {
                                var data = JSON.parse(response);
                                if (data.data == 'Success') {
                                    trackingListener()
                                    $(".ajaxloading").hide();
                                    $(".succMsgMob").html(erroMessage1);
                                    $('body').css('cursor', 'auto');
                                    $(".errormsgMailMob").hide();
                                    $('#fNameMob').val("");
                                    $('#iNameMob').val("");
                                    $('#countryCodeMob').val("");
                                    $('#phoneNoMob').val("");
                                    $('#empNoMob').val("");
                                    $("input[name=email]").val("");
                                    $('.btnContainerMob button').attr('disabled', 'false');
                                    $('.btnContainerMob button').css('background', '#EA7421 0% 0% no-repeat padding-box');
                                    $('.sucessstatuscapterra p').append('success');

                                    setTimeout(function () {
                                        return gtag_report_conversion('https://www.playablo.com/playablo-free-trial.html')
                                    }, 1000);


                                }
                                else {
                                    // alert("fail;")
                                    $(".ajaxloading").hide();
                                }

                            }
                        })
                    }
                    
              });



            })
            
            // });
            var cookieWarnCallback = function (accepted) {

                var message = " ";

                document.getElementById('output').innerHTML = message;
                console.log(message);

            };
        </script>
<script>
    //logo slider JS
    // Slider Animation
    $(document).ready(function () {
$(".customer-logos").slick({
slidesToShow: 3,
slidesToScroll: 1,
autoplay: true,
autoplaySpeed: 500,
arrows: false,
dots: false,
infinite: true,
pauseOnHover: true,
responsive: [
{
breakpoint: 768,
settings: {
  slidesToShow: 4,
},
},
{
breakpoint: 520,
settings: {
  slidesToShow: 3,
},
},
],
});
});

// Slick slider and Lightbox2 Remove clones
$(".customer-logosr .slick-slide.slick-cloned a").removeAttr("data-lightbox");

// client-name-7
// slide sld-img-1
// Handle hover effects with handling for cloned slides while infinite set to true
setTimeout(function () {
let allSlides = document.querySelectorAll(".sld-img");
allSlides = Array.from(allSlides);
console.log(allSlides);

// Add event listener on all slides
allSlides.map((e) => {
e.addEventListener("mouseover", handleMouseHover);
e.addEventListener("mouseout", handleMouseOut);
});

function handleMouseHover(evt) {
// console.log(evt.target.className);
let cName = evt.target.className;
console.log(cName);
let finalClassName = cName.split(" ")[1].split("-")[2];
let clientNameVar = "." + `client-name-${finalClassName}`;
let allElems = document.querySelectorAll(clientNameVar);
allElems = Array.from(allElems);
allElems.map((e) => {
e.style.display = "flex";
});
}

function handleMouseOut(evt) {
let cName = evt.target.className;
console.log(cName);
let finalClassName = cName.split(" ")[1].split("-")[2];
let clientNameVar = "." + `client-name-${finalClassName}`;
let allElems = document.querySelectorAll(clientNameVar);
allElems = Array.from(allElems);
allElems.map((e) => {
e.style.display = "none";
});
}
}, 500);

</script>

<script>
    //testimonial slider js
    var slideIndex = 1;
    showSlides(slideIndex);
    
    function plusSlides(n) {
      showSlides(slideIndex += n);
    }
    
    function currentSlide(n) {
      showSlides(slideIndex = n);
    }
    
    function showSlides(n) {
      var i;
      var slides = document.getElementsByClassName("testimonials-mySlides");
      var dots = document.getElementsByClassName("testimonials-dot");
      if (n > slides.length) {slideIndex = 1}    
      if (n < 1) {slideIndex = slides.length}
      for (i = 0; i < slides.length; i++) {
          slides[i].style.display = "none";  
      }
      for (i = 0; i < dots.length; i++) {
          dots[i].className = dots[i].className.replace(" active", "");
      }
      slides[slideIndex-1].style.display = "block";  
      dots[slideIndex-1].className += " active";
    }
    </script>
    <script>
        $(function() {
    var top = $('#sidebar').offset().top - parseFloat($('#sidebar').css('marginTop').replace(/auto/, 0));
    var footTop = $('#footer').offset().top - parseFloat($('#footer').css('marginTop').replace(/auto/, 0));

    var maxY = footTop - $('#sidebar').outerHeight();

    $(window).scroll(function(evt) {
        var y = $(this).scrollTop();
        if (y > top) {
            if (y < maxY) {
                $('#sidebar').addClass('fixed').removeAttr('style');
            } else {
                $('#sidebar').removeClass('fixed').css({
                    position: 'absolute',
                    top: (maxY - top) + 'px'
                });
            }
        } 
    });
});
    </script>
    <script>
        function onSubmit(token) {
          document.getElementById("demo-form").submit();
        }
      </script>
        <script> (function () { var v = document.getElementsByClassName("youtube-player"); for (var n = 0; n < v.length; n++) { v[n].onclick = function () { var iframe = document.createElement("iframe"); iframe.setAttribute("src", "//www.youtube-nocookie.com/embed/" + this.dataset.id + "?autoplay=1&autohide=2&border=0&wmode=opaque&enablejsapi=1&rel=" + this.dataset.related + "&controls=" + this.dataset.control + "&showinfo=" + this.dataset.info); iframe.setAttribute("frameborder", "0"); iframe.setAttribute("id", "youtube-iframe"); iframe.setAttribute("style", "width: 100%; height: 100%; position: absolute; top: 0; left: 0;"); if (this.dataset.fullscreen == 1) { iframe.setAttribute("allowfullscreen", ""); } while (this.firstChild) { this.removeChild(this.firstChild); } this.appendChild(iframe); }; } })();</script>
        <script
            type="text/javascript">var $zoho = $zoho || {}; $zoho.salesiq = $zoho.salesiq || { widgetcode: "72c51632a769640393eb310ad53f9d6465240250885f40237e19838cdc02898f1a2010ab7b6727677d37b27582c0e9c4", values: {}, ready: function () { } }; var d = document; s = d.createElement("script"); s.type = "text/javascript"; s.id = "zsiqscript"; s.defer = true; s.src = "https://salesiq.zoho.com/widget"; t = d.getElementsByTagName("script")[0]; t.parentNode.insertBefore(s, t);</script>
            
        </body>

<script>'undefined'=== typeof _trfq || (window._trfq = []);'undefined'=== typeof _trfd && (window._trfd=[]),_trfd.push({'tccl.baseHost':'secureserver.net'},{'ap':'cpsh'},{'server':'sg2plcpnl0060'},{'dcenter':'sg2'},{'cp_id':'1906707'},{'cp_cache':''},{'cp_cl':'6'}) // Monitoring performance to make your website faster. If you want to opt-out, please contact web hosting support.</script><script src='https://img1.wsimg.com/traffic-assets/js/tccl.min.js'></script></html>
# Out:
#   File <tokenize>:30
#     <!-- <meta name="description"
#     ^
# IndentationError: unindent does not match any outer indentation level
